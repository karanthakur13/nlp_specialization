# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                   transcript
# ali        \n \n\n\n\n\n\nALI WONG: BABY COBRA (2016) - F...
# anthony    \n \n\n\n\n\n\nAnthony Jeselnik: Thoughts And ...
# bert       \n \n\n\n\n\n\nBert Kreischer: Hey Big Boy (20...
# bill       \n \n\n\n\n\n\nBILL BURR: I'M SORRY YOU FEEL T...
# bo         \n \n\n\n\n\n\nPage Not Found - Scraps from th...
# catherine  \n \n\n\n\n\n\nCatherine Cohen: The Twist...? ...
# chris      \n \n\n\n\n\n\nChris Rock: Bigger & Blacker (1...
# dave       \n \n\n\n\n\n\nDave Chappelle: The Age of Spin...
# george     \n \n\n\n\n\n\nGeorge Carlin: Doin' It Again (...
# hasan      \n \n\n\n\n\n\nPage Not Found - Scraps from th...
# jim        \n \n\n\n\n\n\nJIM JEFFERIES: BARE (2014) - Fu...
# joe        \n \n\n\n\n\n\nJoe Rogan: Triggered (2016) - T...
# john       \n \n\n\n\n\n\nJohn Mulaney: The Comeback Kid ...
# lee        \n \n\n\n\n\n\nLEE MACK: GOING OUT LIVE (2010)...
# louis      \n \n\n\n\n\n\nLOUIS C.K.: OH MY GOD (2013) - ...
# mike       \n \n\n\n\n\n\nMike Birbiglia: My Girlfriend's...
# moses      \n \n\n\n\n\n\nMoses Storm: Trash White (2022)...
# ramy       \n \n\n\n\n\n\nRAMY YOUSSEF: FEELINGS (2019) -...
# ricky      \n \n\n\n\n\n\nRicky Gervais: Humanity (2018) ...
# ronny      \n \n\n\n\n\n\nRONNY CHIENG: ASIAN COMEDIAN DE...
# tiffany    \n \n\n\n\n\n\nTiffany Haddish: Black Mitzvah ...
# tom        \n \n\n\n\n\n\nTom Papa: Human Mule (2016) - T...

# %%
# Apply a first round of text cleaning techniques
import re
import string

def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

round1 = lambda x: clean_text_round1(x)

# %%
# Let's take a look at the updated text
data_clean = pd.DataFrame(data.transcript.apply(round1))
data_clean
# Out:
#                                                                                                                                                       transcript
# ali         ali wong baby cobra full transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv ...
# anthony     anthony jeselnik thoughts and prayers full transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubr...
# bert        bert kreischer hey big boy transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaelt...
# bill        bill burr im sorry you feel that way full transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubri...
# bo          page not found scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcr...
# catherine   catherine cohen the twist shes gorgeous transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrick...
# chris       chris rock bigger blacker transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv...
# dave        dave chappelle the age of spin transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline k...
# george      george carlin doin it again transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kael...
# hasan       page not found scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcr...
# jim         jim jefferies bare full transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv s...
# joe         joe rogan triggered transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv serie...
# john        john mulaney the comeback kid transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline ka...
# lee         lee mack going out live full transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kae...
# louis       louis ck oh my god full transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv s...
# mike        mike birbiglia my girlfriends boyfriend transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrick...
# moses       moses storm trash white transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv s...
# ramy        ramy youssef feelings full transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaelt...
# ricky       ricky gervais humanity transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv se...
# ronny       ronny chieng asian comedian destroys america transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley ku...
# tiffany     tiffany haddish black mitzvah transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline ka...
# tom         tom papa human mule transcript scraps from the loft \r\t\tskip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv serie...

# %%
# Apply a second round of cleaning
def clean_text_round2(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('\n', '', text)
    text = re.sub('\t', '', text)
    text = re.sub('\r', '', text)
    text = re.sub(' +', ' ', text)
    text = re.sub('♪', '', text)
    text = re.sub(r'–\b|\b–', "", text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
data_clean = pd.DataFrame(data_clean.transcript.apply(round2))
data_clean
# Out:
#                                                                                                                                                       transcript
# ali         ali wong baby cobra full transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv series...
# anthony     anthony jeselnik thoughts and prayers full transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpau...
# bert        bert kreischer hey big boy transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seri...
# bill        bill burr im sorry you feel that way full transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpaul...
# bo          page not found scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcriptsco...
# catherine   catherine cohen the twist shes gorgeous transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpaulin...
# chris       chris rock bigger blacker transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv serie...
# dave        dave chappelle the age of spin transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv ...
# george      george carlin doin it again transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv ser...
# hasan       page not found scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcriptsco...
# jim         jim jefferies bare full transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriest...
# joe         joe rogan triggered transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv sh...
# john        john mulaney the comeback kid transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv s...
# lee         lee mack going out live full transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv se...
# louis       louis ck oh my god full transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriest...
# mike        mike birbiglia my girlfriends boyfriend transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpaulin...
# moses       moses storm trash white transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriest...
# ramy        ramy youssef feelings full transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seri...
# ricky       ricky gervais humanity transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv...
# ronny       ronny chieng asian comedian destroys america transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickp...
# tiffany     tiffany haddish black mitzvah transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv s...
# tom         tom papa human mule transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv sh...

# %%
data = data_clean

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['ali']
ali_text[:2000]
# Out:
# ' ali wong baby cobra full transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcriptscomedystandup comedy transcriptsgeorge carlindave chappelleinterviewsplayboy interviewsmusichistorybooks menumoviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcriptscomedystandup comedy transcriptsgeorge carlindave chappelleinterviewsplayboy interviewsmusichistorybooks search moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcriptscomedystandup comedy transcriptsgeorge carlindave chappelleinterviewsplayboy interviewsmusichistorybooks menumoviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcriptscomedystandup comedy transcriptsgeorge carlindave chappelleinterviewsplayboy interviewsmusichistorybooks searchcomedy ali wong baby cobra – full transcript september ali wongs stand up special delves into her sexual adventures hoarding the rocky road to pregnancy and why feminism is terrible ladies and gentlemen please welcome to the stage ali wong hi hello welcome thank you thank you for coming hello hello we are gonna have to get this shit over with cause i have to pee in like ten minutes but thank you everybody so much for comingum its a very exciting day for me its been a very exciting year for me i turned this year yes thank you five people i appreciate that uh i can tell that im getting older because now when i see an girl my automatic thought is fuck you fuck you i dont even know you but fuck you cause im straight up jealous im jealous first and foremost of their metabolism because girls they could just eat like shit and then they take a shit and have a sixpack right they got thatthat beautiful inner thigh clearance where they put their feet together and theres that huge gap here with the light of potential just radiating throughand then when they go to sleep they just go to sleep right they dont have inso'

# %%
# Extract only Ali Wong's text
joe_text = data.transcript.loc['joe']
joe_text[:2000]
# Out:
# ' joe rogan triggered transcript scraps from the loft skip to content moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcriptscomedystandup comedy transcriptsgeorge carlindave chappelleinterviewsplayboy interviewsmusichistorybooks menumoviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcriptscomedystandup comedy transcriptsgeorge carlindave chappelleinterviewsplayboy interviewsmusichistorybooks search moviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcriptscomedystandup comedy transcriptsgeorge carlindave chappelleinterviewsplayboy interviewsmusichistorybooks menumoviesmovie reviewsmovie transcriptsstanley kubrickpauline kaeltv seriestv show transcriptscomedystandup comedy transcriptsgeorge carlindave chappelleinterviewsplayboy interviewsmusichistorybooks searchcomedy joe rogan triggered – transcript august unleashing his inquisitive intense comedic style rogan explores everything from why no one wants to be a president to people who comments on youtube videos from bruce jenner to debbie ladies and gentlemen welcome joe roganwhat the fck is going on san francisco thanks for coming i appreciate it god damn put your phone down fckface i see you btch put your phone down motherfckers they cant use their eyes everybodys gotta live through their goddamn phone whoo im high as fck whoo its strange i wasnt sure if i was gonna do this sober im like ugh its not the move not in san francisco this is i love pot but the people that are making edibles need to slow the fck down oh my god what are you trying to do to peoplei had a pot gummy bear the other day i think we can all agree a gummy bear shouldnt be able to steal your soul right how the fck are these people making these things man theyre not consistent thats also part of the problem you dont know what youre getting cause theyre not making them the same place where they make tylenol nah its some greasy dude with a grateful d'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'': ['ali'],
#  'ali': ['wong', 'wong', 'wongs', 'wong', 'you', 'we', 'why', 'did', 'wong'],
#  'wong': ['baby', 'baby', 'hi', 'have', 'standup'],
#  'baby': ['cobra',
#   'cobra',
#   'wipe',
#   'theyll',
#   'that',
#   'and',
#   'comes',
#   'hasnt',
#   'can',
#   'can',
#   'from'],
#  'cobra': ['full', '–'],
#  'full': ['transcript', 'transcript', 'blown'],
#  'transcript': ['scraps', 'september'],
#  'scraps': ['from', 'from'],
#  'from': ['the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'pier',
#   'harvard',
#   'the',
#   'the',
#   'having',
#   'having',
#   'the',
#   'this',
#   'pedestrians',
#   'their',
#   'a',
#   'thats',
#   'holding',
#   'bacteria',
#   'harvard',
#   'tight',
#   'the'],
#  'the': ['loft',
#   'rocky',
#   'stage',
#   'light',
#   'chatter',
#   'kind',
#   'kind',
#   'presence',
#   'lifechanging',
#   'center',
#   'hoarding',
#   'hpv',
#   'country',
#   'third',
#   'communiststhe',
#   'worst',
#   'manual',
#   'calculator',
#   'future',
#   'tesla',
#   'manual',
#   'way',
#   'lucky',
#   'outside',
#   'inside',
#   'first',
#   'time',
#   'fifth',
#   'next',
#   'back',
#   'park',
#   'middle',
#   'money',
#   'colonizer',
#   'advantage',
#   'time',
#   'sexiest',
#   'sexiest',
#   'neck',
#   'last',
#   'rug',
#   'umami',
#   'difference',
#   'fancy',
#   'chinese',
#   'japanese',
#   'east',
#   'west',
#   'name',
#   'bathroom',
#   'bathroom',
#   'corner',
#   'wait',
#   'wall',
#   'fuck',
#   'househim',
#   'idea',
#   'mans',
#   'message',
#   'whole',
#   'shit',
#   'fuck',
#   'woman',
#   'exact',
#   'following',
#   'goodness',
#   'coo',
#   'table',
#   'top',
#   'fuck',
#   'worst',
#   'smart',
#   'next',
#   'secret',
#   'phrase',
#   'street',
#   'boat',
#   'best',
#   'desert',
#   'stall',
#   'end',
#   'day',
#   'goonies',
#   'velocity',
#   'butt',
#   'doo',
#   'toilet',
#   'ends',
#   'toilet',
#   'toilet',
#   'other',
#   'nerve',
#   'same',
#   'rest',
#   'promise',
#   'images',
#   'internet',
#   'back',
#   'internet',
#   'jewish',
#   'universe',
#   'pain',
#   'pain',
#   'pain',
#   'dick',
#   'butt',
#   'tushtush',
#   'man',
#   'look',
#   'mans',
#   'first',
#   'woman',
#   'lord',
#   'rim',
#   'most',
#   'most',
#   'woman',
#   'time',
#   'boss',
#   'boss',
#   'time',
#   'bedroom',
#   'boss',
#   'real',
#   'word',
#   'word',
#   'right',
#   'point',
#   'kind',
#   'case',
#   'audience',
#   'mom',
#   'fucking',
#   'babys',
#   'dream',
#   'point',
#   'ultimate',
#   'world',
#   'rest',
#   'galapagos',
#   'phrase',
#   'women',
#   'side',
#   'hood',
#   'movie',
#   'park',
#   'sun',
#   'sun',
#   'tupac',
#   'time',
#   'time',
#   'peace',
#   'boat',
#   'pill',
#   'progesterone',
#   'conference',
#   'urge',
#   'hood',
#   'eggs',
#   'month',
#   'kraken',
#   'time',
#   'smiley',
#   'ovulation',
#   'time',
#   'image',
#   'back',
#   'expression',
#   'fuck',
#   'indication',
#   'eye',
#   'shit',
#   'doctor',
#   'lord',
#   'size',
#   'twins',
#   'toilet',
#   'whole',
#   'fuck',
#   'marriage',
#   'pain',
#   'table',
#   'labor',
#   'floor',
#   'love',
#   'real',
#   'baby',
#   'house',
#   'dishes',
#   'plants',
#   'channeli',
#   'star',
#   'show',
#   'camera',
#   'hero',
#   'baby',
#   'baby',
#   'kind',
#   'baby',
#   'same',
#   'escrow',
#   'one',
#   'epicenter',
#   'midterm',
#   'hilarious',
#   'record',
#   'highest',
#   'loft'],
#  'loft': ['skip', 'all'],
#  'skip': ['to'],
#  'to': ['content',
#   'pregnancy',
#   'the',
#   'get',
#   'pee',
#   'sleep',
#   'sleep',
#   'have',
#   'take',
#   'calm',
#   'sleep',
#   'declutter',
#   'achieve',
#   'help',
#   'a',
#   'let',
#   'buy',
#   'clean',
#   'be',
#   'deepakoprah',
#   'achieve',
#   'a',
#   'trap',
#   'it',
#   'date',
#   'any',
#   'cool',
#   'be',
#   'go',
#   'say',
#   'a',
#   'be',
#   'do',
#   'private',
#   'this',
#   'see',
#   'leave',
#   'private',
#   'backpack',
#   'do',
#   'shut',
#   'go',
#   'be',
#   'do',
#   'incept',
#   'leave',
#   'go',
#   'my',
#   'send',
#   'him',
#   'be',
#   'sit',
#   'the',
#   'lie',
#   'women',
#   'be',
#   'continue',
#   'do',
#   'have',
#   'show',
#   'work',
#   'earn',
#   'shit',
#   'seat',
#   'eat',
#   'pull',
#   'ration',
#   'try',
#   'make',
#   'moisten',
#   'come',
#   'start',
#   'you',
#   'make',
#   'just',
#   'the',
#   'podcasts',
#   'me',
#   'come',
#   'me',
#   'get',
#   'work',
#   'eat',
#   'tell',
#   'get',
#   'you',
#   'make',
#   'fuck',
#   'marry',
#   'turn',
#   'youi',
#   'put',
#   'do',
#   'because',
#   'help',
#   'now',
#   'show',
#   'spank',
#   'abuse',
#   'be',
#   'be',
#   'do',
#   'her',
#   'use',
#   'say',
#   'like',
#   'get',
#   'like',
#   'the',
#   'take',
#   'see',
#   'think',
#   'heal',
#   'me',
#   'me',
#   'live',
#   'die',
#   'hide',
#   'alert',
#   'have',
#   'keep',
#   'go',
#   'be',
#   'support',
#   'be',
#   'the',
#   'protect',
#   'see',
#   'have',
#   'show',
#   'be',
#   'get',
#   'get',
#   'take',
#   'act',
#   'find',
#   'discretely',
#   'immediately',
#   'be',
#   'smell',
#   'smell',
#   'protect',
#   'see',
#   'have',
#   'get',
#   'save',
#   'be',
#   'close',
#   'shut',
#   'see',
#   'finish',
#   'finish',
#   'come',
#   'make',
#   'be',
#   'be',
#   'be',
#   'me',
#   'do',
#   'do',
#   'see',
#   'hire',
#   'keyser',
#   'freak',
#   'freak',
#   'it',
#   'cleanse',
#   'assist',
#   'make',
#   'do',
#   'be',
#   'be',
#   'all',
#   'all',
#   'go',
#   'those',
#   'see',
#   'chip',
#   'keep',
#   'get',
#   'protect',
#   'trap',
#   'propose',
#   'me',
#   'harvard',
#   'fame',
#   'ugly',
#   'why',
#   'read'],
#  'content': ['moviesmovie'],
#  'moviesmovie': ['reviewsmovie', 'reviewsmovie'],
#  'reviewsmovie': ['transcriptsstanley',
#   'transcriptsstanley',
#   'transcriptsstanley',
#   'transcriptsstanley'],
#  'transcriptsstanley': ['kubrickpauline',
#   'kubrickpauline',
#   'kubrickpauline',
#   'kubrickpauline'],
#  'kubrickpauline': ['kaeltv', 'kaeltv', 'kaeltv', 'kaeltv'],
#  'kaeltv': ['seriestv', 'seriestv', 'seriestv', 'seriestv'],
#  'seriestv': ['show', 'show', 'show', 'show'],
#  'show': ['transcriptscomedystandup',
#   'transcriptscomedystandup',
#   'transcriptscomedystandup',
#   'transcriptscomedystandup',
#   'he',
#   'off',
#   'i',
#   'him',
#   'signs',
#   'theres',
#   'transcriptsblog'],
#  'transcriptscomedystandup': ['comedy', 'comedy', 'comedy', 'comedy'],
#  'comedy': ['transcriptsgeorge',
#   'transcriptsgeorge',
#   'transcriptsgeorge',
#   'transcriptsgeorge',
#   'roots'],
#  'transcriptsgeorge': ['carlindave',
#   'carlindave',
#   'carlindave',
#   'carlindave',
#   'carlin'],
#  'carlindave': ['chappelleinterviewsplayboy',
#   'chappelleinterviewsplayboy',
#   'chappelleinterviewsplayboy',
#   'chappelleinterviewsplayboy'],
#  'chappelleinterviewsplayboy': ['interviewsmusichistorybooks',
#   'interviewsmusichistorybooks',
#   'interviewsmusichistorybooks',
#   'interviewsmusichistorybooks'],
#  'interviewsmusichistorybooks': ['menumoviesmovie',
#   'search',
#   'menumoviesmovie',
#   'searchcomedy'],
#  'menumoviesmovie': ['reviewsmovie', 'reviewsmovie'],
#  'search': ['moviesmovie'],
#  'searchcomedy': ['ali'],
#  '–': ['full', 'snl'],
#  'september': ['ali'],
#  'wongs': ['stand'],
#  'stand': ['up'],
#  'up': ['special',
#   'jealous',
#   'hpv',
#   'yes',
#   'your',
#   'when',
#   'a',
#   'on',
#   'with',
#   'in',
#   'afterwards',
#   'on',
#   'like',
#   'going',
#   'for',
#   'on',
#   'and',
#   'fine',
#   'dont',
#   'about',
#   'dont',
#   'a',
#   'to',
#   'a',
#   'to',
#   'with',
#   'you',
#   'so',
#   'there',
#   'on',
#   'shes',
#   'the',
#   'myself',
#   'and',
#   'from',
#   'your',
#   'and',
#   'soldier',
#   'in'],
#  'special': ['delves'],
#  'delves': ['into'],
#  'into': ['her',
#   'cervical',
#   'a',
#   'the',
#   'a',
#   'the',
#   'banana',
#   'the',
#   'the',
#   'the',
#   'a',
#   'pleasure',
#   'a',
#   'my',
#   'your',
#   'a',
#   'the'],
#  'her': ['sexual',
#   'get',
#   'to',
#   'book',
#   'lululemon',
#   'butt',
#   'there',
#   'its',
#   'nipples',
#   'pussy',
#   'white',
#   'mexican',
#   'and',
#   'i',
#   'generationgabriel'],
#  'sexual': ['adventures'],
#  'adventures': ['hoarding'],
#  'hoarding': ['the', 'problem', 'goes', 'problem'],
#  'rocky': ['road'],
#  'road': ['to'],
#  'pregnancy': ['and'],
#  'and': ['why',
#   'gentlemen',
#   'foremost',
#   'then',
#   'have',
#   'theres',
#   'resentment',
#   'get',
#   'get',
#   'says',
#   'my',
#   'she',
#   'snatch',
#   'running',
#   'fighting',
#   'yelling',
#   'it',
#   'everybody',
#   'my',
#   'she',
#   'i',
#   'im',
#   'uh',
#   'i',
#   'i',
#   'the',
#   'i',
#   'i',
#   'has',
#   'i',
#   'we',
#   'we',
#   'then',
#   'i',
#   'watched',
#   'i',
#   'have',
#   'that',
#   'you',
#   'recycling',
#   'disturbing',
#   'its',
#   'all',
#   'just',
#   'then',
#   'be',
#   'halfvietnamese',
#   'we',
#   'his',
#   'i',
#   'slide',
#   'your',
#   'inflamed',
#   'youre',
#   'then',
#   'i',
#   'halfjapanese',
#   'im',
#   'halfvietnamese',
#   'halfjungle',
#   'playing',
#   'rugby',
#   'on',
#   'foremost',
#   'a',
#   'the',
#   'emotionally',
#   'i',
#   'percent',
#   'so',
#   'neither',
#   'i',
#   'i',
#   'then',
#   'its',
#   'find',
#   'start',
#   'just',
#   'caves',
#   'gets',
#   'is',
#   'then',
#   'look',
#   'like',
#   'very',
#   'for',
#   'i',
#   'she',
#   'rise',
#   'her',
#   'be',
#   'eat',
#   'watch',
#   'then',
#   'be',
#   'now',
#   'theyre',
#   'most',
#   'theyll',
#   'in',
#   'then',
#   'digitally',
#   'then',
#   'you',
#   'youre',
#   'then',
#   'then',
#   'then',
#   'then',
#   'steady',
#   'brings',
#   'let',
#   'reverberate',
#   'say',
#   'my',
#   'he',
#   'when',
#   'im',
#   'just',
#   'i',
#   'what',
#   'sicker',
#   'sicker',
#   'sicker',
#   'sicker',
#   'posted',
#   'all',
#   'theyre',
#   'thats',
#   'lies',
#   'as',
#   'treat',
#   'youll',
#   'succeed',
#   'they',
#   'i',
#   'you',
#   'its',
#   'then',
#   'thats',
#   'be',
#   'im',
#   'i',
#   'just',
#   'sisters',
#   'a',
#   'unusual',
#   'theyll',
#   'boring',
#   'all',
#   'their',
#   'wearing',
#   'famous',
#   'they',
#   'youre',
#   'just',
#   'therefore',
#   'you',
#   'ignore',
#   'then',
#   'she',
#   'when',
#   'the',
#   'biggie',
#   'it',
#   'it',
#   'my',
#   'your',
#   'there',
#   'i',
#   'a',
#   'i',
#   'push',
#   'then',
#   'then',
#   'melt',
#   'i',
#   'then',
#   'then',
#   'sniff',
#   'i',
#   'youve',
#   'i',
#   'outside',
#   'as',
#   'rapey',
#   'they',
#   'um',
#   'most',
#   'see',
#   'id',
#   'i',
#   'he',
#   'instead',
#   'then',
#   'then',
#   'remember',
#   'then',
#   'hold',
#   'i',
#   'do',
#   'then',
#   'to',
#   'a',
#   'a',
#   'terrible',
#   'i',
#   'when',
#   'everything',
#   'the',
#   'i',
#   'then',
#   'i',
#   'most',
#   'i',
#   'he',
#   'i',
#   'held',
#   'got',
#   'i',
#   'your',
#   'just',
#   'he',
#   'i',
#   'it',
#   'leaves',
#   'dark',
#   'then',
#   'naked',
#   'a',
#   'i',
#   'i',
#   'my',
#   'then',
#   'then',
#   'recently',
#   'uh',
#   'me',
#   'now',
#   'a',
#   'donald',
#   'why',
#   'where'],
#  'why': ['feminism',
#   'people',
#   'you',
#   'else',
#   'you',
#   'are',
#   'are',
#   'dont',
#   'were',
#   'im',
#   'is',
#   'else',
#   'artists',
#   'every'],
#  'feminism': ['is', 'is'],
#  'is': ['terrible',
#   'fuck',
#   'a',
#   'turning',
#   'all',
#   'the',
#   'from',
#   'those',
#   'it',
#   'that',
#   'a',
#   'a',
#   'that',
#   'asian',
#   'turning',
#   'that',
#   'built',
#   'all',
#   'the',
#   'too',
#   'like',
#   'always',
#   'called',
#   'the',
#   'a',
#   'its',
#   'to',
#   'that',
#   'doo',
#   'i',
#   'unfortunately',
#   'what',
#   'a',
#   'a',
#   'at',
#   'the',
#   'a',
#   'going',
#   'so',
#   'not',
#   'not',
#   'not',
#   'most',
#   'when',
#   'fine',
#   'very',
#   'about',
#   'very',
#   'very',
#   'a',
#   'mysterious',
#   'you',
#   'thats',
#   'so',
#   'it'],
#  'terrible': ['ladies', 'i'],
#  'ladies': ['and', 'go', 'who', 'they', 'and', 'who'],
#  'gentlemen': ['please'],
#  'please': ['welcome', 'no', 'hurry', 'look'],
#  'welcome': ['to', 'thank'],
#  'stage': ['ali', 'a', 'movies'],
#  'hi': ['hello'],
#  'hello': ['welcome', 'hello', 'we'],
#  'thank': ['you', 'you', 'you', 'you', 'youmoreali'],
#  'you': ['thank',
#   'for',
#   'everybody',
#   'five',
#   'fuck',
#   'i',
#   'but',
#   'cause',
#   'dont',
#   'go',
#   'go',
#   'dont',
#   'a',
#   'can',
#   'never',
#   'better',
#   'under',
#   'never',
#   'might',
#   'die',
#   'wanna',
#   'wanna',
#   'gotta',
#   'homeless',
#   'a',
#   'drop',
#   'know',
#   'go',
#   'know',
#   'feel',
#   'feel',
#   'know',
#   'feel',
#   'know',
#   'about',
#   'to',
#   'know',
#   'know',
#   'right',
#   'knowbut',
#   'get',
#   'get',
#   'like',
#   'dont',
#   'knowmy',
#   'guys',
#   'know',
#   'mess',
#   'guys',
#   'know',
#   'can',
#   'can',
#   'eat',
#   'queef',
#   'know',
#   'gotta',
#   'know',
#   'marry',
#   'something',
#   'like',
#   'would',
#   'dont',
#   'know',
#   'know',
#   'have',
#   'could',
#   'can',
#   'always',
#   'hurry',
#   'never',
#   'dare',
#   'know',
#   'deep',
#   'need',
#   'need',
#   'dont',
#   'not',
#   'guys',
#   'guys',
#   'wanna',
#   'guys',
#   'telling',
#   'tell',
#   'son',
#   'start',
#   'crave',
#   'realize',
#   'know',
#   'aint',
#   'now',
#   'have',
#   'gotta',
#   'gotta',
#   'dont',
#   'gotta',
#   'put',
#   'know',
#   'havent',
#   'only',
#   'know',
#   'stick',
#   'know',
#   'just',
#   'as',
#   'knowmy',
#   'ok',
#   'all',
#   'know',
#   'right',
#   'respect',
#   'need',
#   'know',
#   'know',
#   'what',
#   'be',
#   'so',
#   'have',
#   'know',
#   'know',
#   'know',
#   'guys',
#   'theres',
#   'know',
#   'gonna',
#   'just',
#   'knowanother',
#   'gonna',
#   'just',
#   'want',
#   'know',
#   'knowi',
#   'remember',
#   'were',
#   'just',
#   'could',
#   'throw',
#   'could',
#   'i',
#   'ghostbustersi',
#   'scratch',
#   'can',
#   'urgently',
#   'cause',
#   'gotta',
#   'need',
#   'guys',
#   'do',
#   'pee',
#   'when',
#   'when',
#   'to',
#   'know',
#   'that',
#   'look',
#   'watch',
#   'know',
#   'know',
#   'know',
#   'that',
#   'push',
#   'push',
#   'push',
#   'just',
#   'think',
#   'boom',
#   'wash',
#   'water',
#   'makin',
#   'change',
#   'about',
#   'get',
#   'know',
#   'know',
#   'you',
#   'you',
#   'owe',
#   'my',
#   'see',
#   'know',
#   'know',
#   'think'],
#  'for': ['coming',
#   'comingum',
#   'me',
#   'me',
#   'me',
#   'my',
#   'fashion',
#   'warmth',
#   'marriage',
#   'them',
#   'the',
#   'a',
#   'the',
#   'four',
#   'five',
#   'five',
#   'the',
#   'us',
#   'fresh',
#   'but',
#   'me',
#   'them',
#   'his',
#   'the',
#   'once',
#   'the',
#   'thats',
#   'all',
#   'the',
#   'me',
#   'me',
#   'me',
#   'a',
#   'them',
#   'granted',
#   'a',
#   'a',
#   'me',
#   'a',
#   'days',
#   'days',
#   'coming',
#   'the',
#   'playing',
#   'being',
#   'doing',
#   'receiving'],
#  'coming': ['hello', 'you', 'to', 'true'],
#  'we': ['are',
#   'were',
#   'were',
#   'were',
#   'had',
#   'had',
#   'had',
#   'the',
#   'were',
#   'were',
#   'spend',
#   'need',
#   'both',
#   'like',
#   'like',
#   'do',
#   'do',
#   'pay',
#   'do',
#   'eat',
#   'eat',
#   'eat',
#   'do',
#   'are',
#   'have',
#   'got',
#   'as',
#   'had',
#   'could',
#   'dont',
#   'better',
#   'could',
#   'could',
#   'have',
#   'had',
#   'walk',
#   'just',
#   'all',
#   'dont',
#   'live',
#   'wouldnt',
#   'got',
#   'got',
#   'bought',
#   'die'],
#  'are': ['gonna',
#   'shocked',
#   'very',
#   'the',
#   'the',
#   'both',
#   'big',
#   'white',
#   'always',
#   'free',
#   'you',
#   'you',
#   'ceos',
#   'never',
#   'like',
#   'a',
#   'you',
#   'you',
#   'like',
#   'your',
#   'droppin',
#   'in',
#   'you',
#   'marked'],
#  'gonna': ['have',
#   'turn',
#   'die',
#   'overtake',
#   'have',
#   'trap',
#   'propose',
#   'stick',
#   'recognize',
#   'see',
#   'be',
#   'have',
#   'live',
#   'tell',
#   'happen',
#   'have',
#   'become',
#   'disappear',
#   'become',
#   'have',
#   'before',
#   'make',
#   'be',
#   'recycle',
#   'burn',
#   'be',
#   'poop',
#   'be'],
#  'have': ['to',
#   'to',
#   'a',
#   'insomnia',
#   'to',
#   'their',
#   'hpv',
#   'it',
#   'hpv',
#   'hpv',
#   'one',
#   'the',
#   'the',
#   'a',
#   'a',
#   'to',
#   'a',
#   'a',
#   'these',
#   'done',
#   'been',
#   'any',
#   'so',
#   'to',
#   'your',
#   'to',
#   'to',
#   'executive',
#   'some',
#   'a',
#   'a',
#   'a',
#   'had',
#   'children',
#   'any',
#   'a',
#   'to',
#   'a',
#   'sex',
#   'to',
#   'had',
#   'to',
#   'the',
#   'a'],
#  'get': ['this',
#   'it',
#   'it',
#   'rid',
#   'it',
#   'to',
#   'to',
#   'to',
#   'the',
#   'very',
#   'very',
#   'to',
#   'to',
#   'my',
#   'sicker',
#   'sicker',
#   'really',
#   'a',
#   'a',
#   'all',
#   'us',
#   'to',
#   'pregnant',
#   'pregnant',
#   'up',
#   'into',
#   'older',
#   'as',
#   'a',
#   'pregnant',
#   'pregnant',
#   'that',
#   'my',
#   'pregnant',
#   'huge',
#   'dark',
#   'big',
#   'big',
#   'all',
#   'pregnant'],
#  'this': ['shit',
#   'year',
#   'doctor',
#   'shit',
#   'shit',
#   'calculator',
#   'judy',
#   'and',
#   'shit',
#   'past',
#   'past',
#   'wedding',
#   'dude',
#   'guy',
#   'is',
#   'restaurant',
#   'restaurant',
#   'hippydippy',
#   'sneaking',
#   'wacky',
#   'dude',
#   'dude',
#   'bitch',
#   'huge',
#   'shit',
#   'conversation',
#   'is',
#   'fucking',
#   'relatable',
#   'is',
#   'left',
#   'red',
#   'huge',
#   'aggressive',
#   'shit',
#   'shit',
#   'far',
#   'crazy',
#   'shit',
#   'dream',
#   'article',
#   'field'],
#  'shit': ['over',
#   'and',
#   'and',
#   'around',
#   'around',
#   'dont',
#   'up',
#   'is',
#   'my',
#   'on',
#   'like',
#   'we',
#   'outta',
#   'in',
#   'in',
#   'in',
#   'too',
#   'was',
#   'together',
#   'togethermy',
#   'i',
#   'youre',
#   'turns',
#   'its',
#   'they',
#   'you',
#   'out',
#   'that',
#   'over',
#   'at',
#   'on',
#   'around',
#   'anymore',
#   'that'],
#  'over': ['with', 'again', 'again', 'by', 'his'],
#  'with': ['cause',
#   'the',
#   'where',
#   'your',
#   'all',
#   'these',
#   'a',
#   'a',
#   'a',
#   'somebody',
#   'a',
#   'glaucoma',
#   'our',
#   'this',
#   'my',
#   'him',
#   'him',
#   'me',
#   'their',
#   'the',
#   'which',
#   'me',
#   'the',
#   'eyelashes',
#   'my',
#   'a',
#   'male',
#   'your',
#   'no',
#   'me',
#   'it',
#   'you',
#   'intention',
#   'me',
#   'your',
#   'my'],
#  'cause': ['i',
#   'im',
#   'it',
#   'it',
#   'he',
#   'i',
#   'were',
#   'my',
#   'youre',
#   'when',
#   'its',
#   'if',
#   'her',
#   'she',
#   'its',
#   'you',
#   'i',
#   'i'],
#  'i': ['have',
#   'turned',
#   'appreciate',
#   'can',
#   'see',
#   'dont',
#   'have',
#   'have',
#   'have',
#   'can',
#   'turn',
#   'am',
#   'turn',
#   'have',
#   'was',
#   'was',
#   'was',
#   'do',
#   'also',
#   'gave',
#   'dated',
#   'first',
#   'saw',
#   'was',
#   'learned',
#   'was',
#   'trapped',
#   'did',
#   'knew',
#   'was',
#   'thought',
#   'was',
#   'saw',
#   'was',
#   'knew',
#   'was',
#   'dropped',
#   'was',
#   'just',
#   'dont',
#   'get',
#   'mean',
#   'just',
#   'could',
#   'could',
#   'think',
#   'was',
#   'dont',
#   'did',
#   'go',
#   'have',
#   'read',
#   'was',
#   'pee',
#   'need',
#   'are',
#   'had',
#   'i',
#   'just',
#   'had',
#   'just',
#   'wanted',
#   'sent',
#   'told',
#   'bought',
#   'had',
#   'was',
#   'was',
#   'was',
#   'need',
#   'waspeople',
#   'did',
#   'dont',
#   'dont',
#   'straight',
#   'dont',
#   'do',
#   'dont',
#   'dont',
#   'wanna',
#   'want',
#   'think',
#   'guess',
#   'hear',
#   'wanna',
#   'love',
#   'love',
#   'still',
#   'gotta',
#   'literally',
#   'had',
#   'hear',
#   'lose',
#   'heard',
#   'was',
#   'saw',
#   'know',
#   'heard',
#   'wanna',
#   'was',
#   'should',
#   'trapped',
#   'choose',
#   'chose',
#   'said',
#   'do',
#   'really',
#   'dont',
#   'got',
#   'got',
#   'think',
#   'started',
#   'was',
#   'went',
#   'dont',
#   'just',
#   'gotta',
#   'was',
#   'finally',
#   'just',
#   'got',
#   'was',
#   'got',
#   'just',
#   'dont',
#   'dont',
#   'dont',
#   'like',
#   'respect',
#   'know',
#   'dont',
#   'dont',
#   'also',
#   'just',
#   'cant',
#   'can',
#   'told',
#   'want',
#   'wanna',
#   'can',
#   'want',
#   'want',
#   'wanna',
#   'dont',
#   'am',
#   'dare',
#   'just',
#   'identify',
#   'dont',
#   'was',
#   'won',
#   'was',
#   'really',
#   'changed',
#   'changed',
#   'get',
#   'need',
#   'dont',
#   'get',
#   'need',
#   'get',
#   'say',
#   'mean',
#   'know',
#   'slime',
#   'slime',
#   'did',
#   'was',
#   'ate',
#   'found',
#   'had',
#   'would',
#   'had',
#   'had',
#   'want',
#   'wanna',
#   'smell',
#   'smell',
#   'discretely',
#   'were',
#   'would',
#   'would',
#   'need',
#   'want',
#   'was',
#   'would',
#   'would',
#   'know',
#   'could',
#   'would',
#   'would',
#   'learned',
#   'would',
#   'dont',
#   'had',
#   'cant',
#   'wish',
#   'told',
#   'told',
#   'had',
#   'found',
#   'see',
#   'was',
#   'dont',
#   'was',
#   'lost',
#   'sat',
#   'sat',
#   'was',
#   'used',
#   'wanted',
#   'love',
#   'finally',
#   'always',
#   'was',
#   'look',
#   'cant',
#   'can',
#   'am',
#   'am',
#   'didnt',
#   'cant',
#   'get',
#   'do',
#   'i',
#   'i',
#   'like',
#   'berate',
#   'really',
#   'have',
#   'gotta',
#   'didnt',
#   'didnt',
#   'look',
#   'will',
#   'do',
#   'was',
#   'was',
#   'looked',
#   'i',
#   'in',
#   'met',
#   'had',
#   'meet',
#   'discovered',
#   'dont',
#   'want'],
#  'pee': ['in', 'i', 'on'],
#  'in': ['like',
#   'peace',
#   'men',
#   'womens',
#   'the',
#   'books',
#   'the',
#   'handy',
#   'san',
#   'eight',
#   'a',
#   'san',
#   'broad',
#   'the',
#   'a',
#   'america',
#   'a',
#   'my',
#   'it',
#   'the',
#   'and',
#   'men',
#   'i',
#   'my',
#   'well',
#   'ok',
#   'her',
#   'terms',
#   'a',
#   'a',
#   'their',
#   'doo',
#   'the',
#   'the',
#   'the',
#   'her',
#   'different',
#   'my',
#   'time',
#   'the',
#   'the',
#   'his',
#   'his',
#   'bed',
#   'control',
#   'the',
#   'has',
#   'elementary',
#   'the',
#   'their',
#   'a',
#   'between',
#   'my',
#   'front',
#   'the',
#   'your',
#   'when',
#   'your',
#   'such',
#   'the',
#   'atlanta',
#   'their',
#   'front',
#   'my',
#   'labor',
#   'the',
#   'front',
#   'our',
#   'shape',
#   'a',
#   'previously',
#   'debt',
#   'a',
#   'los'],
#  'like': ['ten',
#   'shit',
#   'to',
#   'fifty',
#   'the',
#   'and',
#   'this',
#   'the',
#   'you',
#   'but',
#   'oh',
#   'oh',
#   'all',
#   'we',
#   'hey',
#   'wassup',
#   'hey',
#   'where',
#   'at',
#   'oh',
#   'you',
#   'to',
#   'youre',
#   'voting',
#   'that',
#   'im',
#   'i',
#   'you',
#   'hold',
#   'making',
#   'a',
#   'i',
#   'loofah',
#   'responsibility',
#   'host',
#   'filipino',
#   'its',
#   'its',
#   'private',
#   'to',
#   'to',
#   'that',
#   'freerange',
#   'a',
#   'we',
#   'we',
#   'oh',
#   'im',
#   'shut',
#   'oh',
#   'you',
#   'very',
#   'were',
#   'we',
#   'but',
#   'look',
#   'that',
#   'youre',
#   'wiping',
#   'oh',
#   'its',
#   'you',
#   'hey',
#   'why',
#   'mrs',
#   'uh',
#   'oh',
#   'youre',
#   'i',
#   'oh',
#   'im',
#   'a',
#   'it',
#   'that',
#   'hes',
#   'youre',
#   'yes',
#   'to',
#   'i',
#   'become',
#   'a',
#   'a',
#   'guys',
#   'thats',
#   'ali',
#   'yeah',
#   'why',
#   'yeah',
#   'a',
#   'yeah',
#   'oh',
#   'im',
#   'the',
#   'im',
#   'skittles',
#   'a',
#   'everything',
#   'oh',
#   'only',
#   'were',
#   'release',
#   'a',
#   'we',
#   'ok',
#   'they',
#   'hey',
#   'oh',
#   'uh',
#   'losing',
#   'no',
#   'yes',
#   'you',
#   'yeah',
#   'that',
#   'this',
#   'i',
#   'a',
#   'a',
#   'fingers',
#   'you',
#   'whoppers',
#   'a',
#   'when',
#   'really',
#   'why',
#   'way'],
#  'ten': ['minutes', 'gallons', 'times'],
#  'minutes': ['but'],
#  'but': ['thank',
#   'fuck',
#   'i',
#   'my',
#   'i',
#   'he',
#   'sometimes',
#   'ali',
#   'i',
#   'its',
#   'dont',
#   'i',
#   'i',
#   'im',
#   'my',
#   'what',
#   'hes',
#   'mostly',
#   'im',
#   'its'],
#  'everybody': ['so',
#   'has',
#   'has',
#   'has',
#   'thought',
#   'doesnt',
#   'thought',
#   'thank'],
#  'so': ['much',
#   'basically',
#   'you',
#   'emotional',
#   'emotional',
#   'i',
#   'much',
#   'vulnerable',
#   'smooth',
#   'were',
#   'he',
#   'its',
#   'you',
#   'youre',
#   'that',
#   'good',
#   'i',
#   'many',
#   'that',
#   'that',
#   'when',
#   'in',
#   'that',
#   'in',
#   'motherfucker',
#   'do',
#   'now',
#   'annoying',
#   'i',
#   'that',
#   'embarrassing',
#   'lonely',
#   'juicy',
#   'my',
#   'then',
#   'then',
#   'hot',
#   'that',
#   'tired',
#   'dark',
#   'they',
#   'bad',
#   'bad',
#   'resentful',
#   'much',
#   'you',
#   'little',
#   'little',
#   'supportive',
#   'i',
#   'that',
#   'that',
#   'that',
#   'as'],
#  'much': ['for',
#   'better',
#   'chemistry',
#   'i',
#   'shittier',
#   'netflix',
#   'for',
#   'resentment'],
#  'comingum': ['its'],
#  'its': ['a',
#   'been',
#   'like',
#   'ok',
#   'coming',
#   'undetectable',
#   'really',
#   'a',
#   'too',
#   'very',
#   'hot',
#   'amazing',
#   'what',
#   'like',
#   'so',
#   'all',
#   'its',
#   'different',
#   'authentic',
#   'not',
#   'funny',
#   'too',
#   'a',
#   'a',
#   'probably',
#   'basically',
#   'been',
#   'its',
#   'very',
#   'because',
#   'ok',
#   'like',
#   'like',
#   'the',
#   'because',
#   'sexist',
#   'very',
#   'so',
#   'a',
#   'a',
#   'what',
#   'lonely',
#   'a',
#   'very',
#   'all',
#   'too',
#   'easter',
#   'like',
#   'go',
#   'not',
#   'because',
#   'when',
#   'super',
#   'whatevs',
#   'toll',
#   'different',
#   'not',
#   'straight',
#   'neosporinso'],
#  'a': ['very',
#   'very',
#   'shit',
#   'sixpack',
#   'ambien',
#   'meditation',
#   'fucking',
#   'lot',
#   'ghost',
#   'selfhelp',
#   'horrible',
#   'hoarding',
#   'hoarding',
#   'third',
#   'dictators',
#   'shovel',
#   'climax',
#   'texas',
#   'procrastinator',
#   'lot',
#   'man',
#   'lot',
#   'lot',
#   'grownass',
#   'mattress',
#   'kitchen',
#   'very',
#   'catch',
#   'secret',
#   'public',
#   'hipster',
#   'homeless',
#   'lot',
#   'lot',
#   'major',
#   'yoko',
#   'white',
#   'white',
#   'wes',
#   'lot',
#   'white',
#   'white',
#   'dolphin',
#   'slip',
#   'jewish',
#   'huge',
#   'number',
#   'supply',
#   'grandma',
#   'weekend',
#   'thousand',
#   'shitty',
#   'woman',
#   'new',
#   'man',
#   'pinterest',
#   'saturday',
#   'completely',
#   'lot',
#   'lot',
#   'genius',
#   'housewife',
#   'great',
#   'lot',
#   'great',
#   'office',
#   'office',
#   'office',
#   'day',
#   'sadass',
#   'macgyver',
#   'slow',
#   'lot',
#   'part',
#   'circle',
#   'lot',
#   'im',
#   'disgusting',
#   'pervert',
#   'gross',
#   'very',
#   'young',
#   'idiot',
#   'lot',
#   'result',
#   'little',
#   'second',
#   'whole',
#   'conqueror',
#   'little',
#   'little',
#   'little',
#   'lot',
#   'lot',
#   'magical',
#   'big',
#   'ban',
#   'very',
#   'little',
#   'housewife',
#   'certain',
#   'couple',
#   'dude',
#   'stroll',
#   'sidewalk',
#   'quarter',
#   'princessi',
#   'vietnam',
#   'half',
#   'female',
#   'baby',
#   'week',
#   'little',
#   'sudden',
#   'frozen',
#   'lot',
#   'lot',
#   'kid',
#   'kid',
#   'lot',
#   'kid',
#   'kid',
#   'asian',
#   'billion',
#   'turtle',
#   'right',
#   'uturn',
#   'oturn',
#   'car',
#   'mess',
#   'full',
#   'century',
#   'living',
#   'fuck',
#   'free',
#   'contest',
#   'kid',
#   'bubble',
#   'little',
#   'lot',
#   'smokers',
#   'side',
#   'sandwich',
#   'way',
#   'doctor',
#   'kid',
#   'lot',
#   'lot',
#   'while',
#   'bunch',
#   'dictatorship',
#   'hand',
#   'man',
#   'zombie',
#   'half',
#   'miscarriage',
#   'lot',
#   'miscarriage',
#   'third',
#   'pair',
#   'reason',
#   'heartbeat',
#   'miscarriage',
#   'month',
#   'bike',
#   'doula',
#   'doula',
#   'white',
#   'lot',
#   'soft',
#   'baby',
#   'child',
#   'marriage',
#   'eyeball',
#   'foot',
#   'great',
#   'shitty',
#   'bad',
#   'daily',
#   'daily',
#   'bullseye',
#   'minion',
#   'year',
#   'nude',
#   'half',
#   'bunch',
#   'half',
#   'good',
#   'comment',
#   'name',
#   'speech',
#   'box'],
#  'very': ['exciting',
#   'exciting',
#   'helpful',
#   'lucky',
#   'unusual',
#   'confusing',
#   'you',
#   'picturesque',
#   'you',
#   'underrated',
#   'well',
#   'surprised',
#   'soft',
#   'nurturing',
#   'domestic',
#   'upset',
#   'judgmental',
#   'distracting',
#   'young',
#   'sexually',
#   'roundabout',
#   'rare',
#   'demoralizing',
#   'clinical',
#   'universal',
#   'grateful',
#   'common',
#   'early',
#   'much',
#   'very',
#   'scared'],
#  'exciting': ['day', 'year'],
#  'day': ['for',
#   'let',
#   'yeah',
#   'and',
#   'was',
#   'getting',
#   'jobs',
#   'which',
#   'housewives',
#   'every',
#   'like',
#   'long',
#   'looks',
#   'this',
#   'since',
#   'long',
#   'on'],
#  'me': ['its',
#   'i',
#   'that',
#   'tony',
#   'that',
#   'to',
#   'something',
#   'hes',
#   'off',
#   'feel',
#   'and',
#   'to',
#   'feel',
#   'and',
#   'the',
#   'tell',
#   'cause',
#   'about',
#   'with',
#   'and',
#   'when',
#   'anymore',
#   'and',
#   'to',
#   'and',
#   'this',
#   'on',
#   'when',
#   'this',
#   'and',
#   'ok',
#   'i',
#   'enough',
#   'you',
#   'discouraged',
#   'from',
#   'when',
#   'from',
#   'because',
#   'see',
#   'of',
#   'but',
#   'company',
#   'when',
#   'i',
#   'when',
#   'anymore',
#   'like',
#   'extremely',
#   'because',
#   'in',
#   'thats',
#   'oh',
#   'while',
#   'and',
#   'to',
#   'a',
#   'out',
#   'out',
#   'to',
#   'oh',
#   'im',
#   'im',
#   'i',
#   'money',
#   'in',
#   'for',
#   'out',
#   'oh',
#   'with',
#   'how',
#   'oh'],
#  'been': ['a',
#   'dating',
#   'pressuring',
#   'together',
#   'reading',
#   'to',
#   'run',
#   'eating',
#   'trying',
#   'ali'],
#  'year': ['for', 'yes', 'uh', 'i', 'ive', 'i', 'i'],
#  'turned': ['this'],
#  'yes': ['thank',
#   'yes',
#   'thats',
#   'yes',
#   'yes',
#   'i',
#   'i',
#   'because',
#   'the',
#   'i'],
#  'five': ['people', 'years', 'years'],
#  'people': ['i',
#   'inside',
#   'are',
#   'its',
#   'all',
#   'dont',
#   'until',
#   'doing',
#   'like',
#   'i',
#   'thats',
#   'were',
#   'praise',
#   'dont',
#   'will'],
#  'appreciate': ['that'],
#  'that': ['uh',
#   'im',
#   'huge',
#   'says',
#   'they',
#   'lives',
#   'i',
#   'im',
#   'if',
#   'you',
#   'retainer',
#   'with',
#   'calculator',
#   'bamboozled',
#   'im',
#   'will',
#   'and',
#   'at',
#   'he',
#   'your',
#   'has',
#   'store',
#   'beard',
#   'shit',
#   'and',
#   'privilege',
#   'entitlement',
#   'for',
#   'you',
#   'uh',
#   'bread',
#   'tastes',
#   'lesbian',
#   'seems',
#   'seems',
#   'he',
#   'youre',
#   'i',
#   'i',
#   'so',
#   'hed',
#   'book',
#   'book',
#   'got',
#   'ever',
#   'well',
#   'fucking',
#   'housewife',
#   'bitch',
#   'horrible',
#   'they',
#   'oneply',
#   'office',
#   'they',
#   'your',
#   'the',
#   'no',
#   'shit',
#   'you',
#   'dont',
#   'i',
#   'yyou',
#   'if',
#   'im',
#   'hes',
#   'and',
#   'you',
#   'if',
#   'then',
#   'theyre',
#   'fear',
#   'shit',
#   'fear',
#   'he',
#   'we',
#   'im',
#   'i',
#   'woman',
#   'now',
#   'whole',
#   'whole',
#   'was',
#   'was',
#   'babys',
#   'everybody',
#   'its',
#   'came',
#   'shes',
#   'cause',
#   'to',
#   'you',
#   'snailtrail',
#   'is',
#   'my',
#   'were',
#   'it',
#   'its',
#   'tell',
#   'i',
#   'when',
#   'means',
#   'that',
#   'they',
#   'they',
#   'day',
#   'says',
#   'that',
#   'stupidass',
#   'i',
#   'harvard',
#   'theyre',
#   'im',
#   'i',
#   'shit',
#   'is',
#   'blows',
#   'youre',
#   'you',
#   'that',
#   'happens',
#   'he',
#   'hes',
#   'goes',
#   'i',
#   'they',
#   'the',
#   'the',
#   'im',
#   'my',
#   'reflects'],
#  'uh': ['i',
#   'this',
#   'hes',
#   'between',
#   'you',
#   'we',
#   'youre',
#   'im',
#   'mmm',
#   'yeah',
#   'two'],
#  'can': ['tell',
#   'also',
#   'i',
#   'i',
#   'never',
#   'you',
#   'be',
#   'tell',
#   'tell',
#   'never',
#   'listen',
#   'do',
#   'talk',
#   'comfortably',
#   'tell',
#   'just',
#   'think',
#   'i',
#   'i',
#   'i',
#   'already',
#   'really',
#   'you',
#   'you',
#   'already',
#   'see',
#   'find'],
#  'tell': ['that',
#   'that',
#   'first',
#   'by',
#   'you',
#   'them',
#   'me',
#   'you',
#   'you',
#   'but',
#   'you',
#   'because',
#   'you'],
#  'im': ['getting',
#   'straight',
#   'jealous',
#   'gonna',
#   'getting',
#   'not',
#   'interested',
#   'a',
#   'not',
#   'hoping',
#   'hoping',
#   'gonna',
#   'not',
#   'the',
#   'gonna',
#   'absorbing',
#   'like',
#   'halfchinese',
#   'halfchinese',
#   'just',
#   'a',
#   'very',
#   'like',
#   'done',
#   'done',
#   'not',
#   'a',
#   'a',
#   'a',
#   'a',
#   'scared',
#   'a',
#   'going',
#   'like',
#   'gonna',
#   'gonna',
#   'tired',
#   'the',
#   'the',
#   'talking',
#   'talking',
#   'striving',
#   'a',
#   'a',
#   'guaranteed',
#   'gonna',
#   'like',
#   'still',
#   'just',
#   'older',
#   'not',
#   'just',
#   'only',
#   'only',
#   'gonna',
#   'im',
#   'and',
#   'girl',
#   'from',
#   'im',
#   'very',
#   'going',
#   'all',
#   'busy',
#   'the',
#   'not',
#   'a',
#   'fucked',
#   'not',
#   'seven',
#   'performing'],
#  'getting': ['older', 'older', 'busy', 'massages'],
#  'older': ['because', 'because', 'its', 'when'],
#  'because': ['now',
#   'girls',
#   'its',
#   'my',
#   'my',
#   'you',
#   'what',
#   'according',
#   'before',
#   'i',
#   'usually',
#   'being',
#   'hes',
#   'hes',
#   'i',
#   'you',
#   'i',
#   'you',
#   'i',
#   'the',
#   'he',
#   'you',
#   'theyre',
#   'were',
#   'im',
#   'of',
#   'according',
#   'boys',
#   'female',
#   'they',
#   'im',
#   'were',
#   'uh',
#   'when',
#   'theyre',
#   'theyre',
#   'then',
#   'the',
#   'were',
#   'last',
#   'when',
#   'the',
#   'i',
#   'if',
#   'my',
#   'he'],
#  'now': ['when',
#   'has',
#   'crush',
#   'for',
#   'were',
#   'oh',
#   'but',
#   'if',
#   'because',
#   'instead',
#   'and',
#   'if'],
#  'when': ['i',
#   'they',
#   'a',
#   'youre',
#   'she',
#   'we',
#   'you',
#   'you',
#   'really',
#   'i',
#   'youre',
#   'a',
#   'i',
#   'you',
#   'i',
#   'our',
#   'you',
#   'we',
#   'i',
#   'i',
#   'i',
#   'i',
#   'you',
#   'he',
#   'i',
#   'that',
#   'when',
#   'ive',
#   'you',
#   'youre',
#   'they',
#   'i',
#   'im',
#   'i',
#   'i',
#   'my',
#   'you',
#   'trying',
#   'i',
#   'everything',
#   'i',
#   'can',
#   'can',
#   'can',
#   'in',
#   'youre',
#   'the',
#   'its',
#   'it',
#   'they',
#   'i',
#   'somebody',
#   'somebody',
#   'he',
#   'a',
#   'they',
#   'they',
#   'youre',
#   'they',
#   'i',
#   'i',
#   'theyre',
#   'youre',
#   'you',
#   'he',
#   'you',
#   'i',
#   'it',
#   'its',
#   'its'],
#  'see': ['an',
#   'ten',
#   'on',
#   'that',
#   'the',
#   'a',
#   'a',
#   'how',
#   'that',
#   'whos',
#   'a',
#   'the',
#   'the',
#   'two',
#   'is',
#   'beyoncé',
#   'how',
#   'how',
#   'if',
#   'like',
#   'me'],
#  'an': ['girl', 'atm', 'impression', 'investment', 'attempt'],
#  'girl': ['my', 'because', 'when'],
#  'my': ['automatic',
#   'doctor',
#   'body',
#   'kindle',
#   'home',
#   'optimum',
#   'other',
#   'mom',
#   'life',
#   'generation',
#   'time',
#   'mom',
#   'optimum',
#   'husband',
#   'league',
#   'god',
#   'god',
#   'part',
#   'generation',
#   'volvo',
#   'pussy',
#   'god',
#   'husband',
#   'god',
#   'bed',
#   'husband',
#   'god',
#   'pinterest',
#   'best',
#   'wedding',
#   'husband',
#   'personality',
#   'heart',
#   'financial',
#   'friends',
#   'coworkers',
#   'toilet',
#   'fingers',
#   'coworkers',
#   'coworkers',
#   'shit',
#   'husband',
#   'life',
#   'destiny',
#   'last',
#   'mom',
#   'dad',
#   'grandma',
#   'and',
#   'god',
#   'god',
#   'husband',
#   'asianamerican',
#   'female',
#   'friends',
#   'husband',
#   'mind',
#   'mind',
#   'god',
#   'face',
#   'toyota',
#   'mom',
#   'husband',
#   'destiny',
#   'body',
#   'pussy',
#   'god',
#   'fault',
#   'i',
#   'uterus',
#   'progesterone',
#   'writing',
#   'coworkers',
#   'underwear',
#   'fingers',
#   'fingers',
#   'own',
#   'fingers',
#   'fingers',
#   'fingers',
#   'husband',
#   'god',
#   'husband',
#   'face',
#   'god',
#   'mom',
#   'sixweek',
#   'god',
#   'husband',
#   'miscarriage',
#   'shit',
#   'husband',
#   'husband',
#   'doctors',
#   'god',
#   'blood',
#   'husband',
#   'nipples',
#   'pussys',
#   'pussys',
#   'my',
#   'bodys',
#   'husband',
#   'league',
#   'god',
#   'dreams',
#   'beautiful',
#   'hardearned',
#   'ass'],
#  'automatic': ['thought'],
#  'thought': ['is', 'it', 'they', 'it'],
#  'fuck': ['you',
#   'you',
#   'you',
#   'they',
#   'up',
#   'down',
#   'one',
#   'they',
#   'him',
#   'up',
#   'i'],
#  'dont': ['even',
#   'have',
#   'know',
#   'have',
#   'have',
#   'have',
#   'know',
#   'ever',
#   'even',
#   'know',
#   'know',
#   'gotta',
#   'know',
#   'go',
#   'got',
#   'wanna',
#   'i',
#   'wanna',
#   'feed',
#   'wanna',
#   'wanna',
#   'know',
#   'tell',
#   'think',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'try',
#   'your',
#   'wanna',
#   'wanna',
#   'worry',
#   'cheat',
#   'no',
#   'i',
#   'no',
#   'wanna',
#   'kill',
#   'wanna',
#   'want',
#   'know',
#   'get',
#   'know',
#   'you',
#   'crack',
#   'die',
#   'die',
#   'know',
#   'give',
#   'know',
#   'wanna',
#   'see',
#   'feel',
#   'tell',
#   'work'],
#  'even': ['know', 'know', 'accidentally', 'effective', 'have', 'come'],
#  'know': ['you',
#   'what',
#   'that',
#   'when',
#   'where',
#   'what',
#   'when',
#   'that',
#   'wear',
#   'whats',
#   'because',
#   'you',
#   'white',
#   'its',
#   'just',
#   'why',
#   'oohwee',
#   'the',
#   'learning',
#   'anything',
#   'what',
#   'i',
#   'that',
#   'maybe',
#   'how',
#   'how',
#   'you',
#   'squeeze',
#   'its',
#   'that',
#   'freaked',
#   'i',
#   'and',
#   'especially',
#   'i',
#   'you',
#   'like',
#   'i',
#   'i',
#   'what',
#   'youve',
#   'what',
#   'if',
#   'whats',
#   'a',
#   'the',
#   'why',
#   'whats',
#   'is',
#   'what',
#   'and',
#   'what',
#   'plenty',
#   'what',
#   'what',
#   'that',
#   'i',
#   'your',
#   'that',
#   'that',
#   'they',
#   'and',
#   'i'],
#  'straight': ['up', 'up', 'up'],
#  'jealous': ['im', 'first'],
#  'first': ['and',
#   'met',
#   'thing',
#   'dates',
#   'and',
#   'passively',
#   'youll',
#   'lady',
#   'old',
#   'webmdwhen',
#   'home'],
#  'foremost': ['of', 'by'],
#  'of': ['their',
#   'potential',
#   'regret',
#   'them',
#   'men',
#   'two',
#   'hpv',
#   'wolverine',
#   'grey',
#   'tidying',
#   'success',
#   'all',
#   'my',
#   'shit',
#   'my',
#   'a',
#   'you',
#   'my',
#   'successi',
#   'losers',
#   'losers',
#   'skaters',
#   'my',
#   'my',
#   'people',
#   'opinions',
#   'cool',
#   'that',
#   'that',
#   'your',
#   'our',
#   'our',
#   'los',
#   'all',
#   'bleach',
#   'your',
#   'this',
#   'asian',
#   'us',
#   'the',
#   'my',
#   'facebook',
#   'women',
#   'options',
#   'my',
#   'day',
#   'the',
#   'the',
#   'their',
#   'credence',
#   'my',
#   'privileged',
#   'this',
#   'my',
#   'early',
#   'myself',
#   'women',
#   'of',
#   'the',
#   'the',
#   'crazy',
#   'the',
#   'is',
#   'your',
#   'mine',
#   'resistance',
#   'no',
#   'the',
#   'control',
#   'control',
#   'being',
#   'her',
#   'saying',
#   'saying',
#   'income',
#   'one',
#   'them',
#   'shit',
#   'a',
#   'my',
#   'my',
#   'your',
#   'nowhere',
#   'their',
#   'her',
#   'those',
#   'longevityi',
#   'change',
#   'mother',
#   'science',
#   'that',
#   'my',
#   'the',
#   'people',
#   'fuckin',
#   'the',
#   'that',
#   'angry',
#   'the',
#   'the',
#   'your',
#   'their',
#   'their',
#   'him',
#   'this',
#   'that',
#   'me',
#   'women',
#   'women',
#   'shoes',
#   'poppy',
#   'me',
#   'craigslist',
#   'childbirth',
#   'women',
#   'the',
#   'your',
#   'life',
#   'how',
#   'my',
#   'the',
#   'survival',
#   'another',
#   'those',
#   'body',
#   'losers',
#   'my',
#   'whitecollar',
#   'her',
#   'use',
#   'standup'],
#  'their': ['metabolism',
#   'feet',
#   'whole',
#   'house',
#   'communist',
#   'shit',
#   'doo',
#   'hallways',
#   'ipad',
#   'eyebrows',
#   'prostate',
#   'glasses',
#   'fame',
#   'existence',
#   'their',
#   'bigass',
#   'darth',
#   'archnemesis',
#   'in',
#   'eyes',
#   'eyes',
#   'eyes',
#   'head',
#   'eyelids',
#   'face',
#   'flip',
#   'husbands'],
#  'metabolism': ['because'],
#  'girls': ['they'],
#  'they': ['could',
#   'take',
#   'got',
#   'put',
#   'go',
#   'just',
#   'dont',
#   'dont',
#   'have',
#   'dont',
#   'just',
#   'have',
#   'were',
#   'like',
#   'teach',
#   'introduce',
#   'got',
#   'just',
#   'get',
#   'mean',
#   'ruined',
#   'dont',
#   'dont',
#   'dont',
#   'dont',
#   'dont',
#   'purposely',
#   'try',
#   'dont',
#   'dont',
#   'dont',
#   'want',
#   'dont',
#   'can',
#   'can',
#   'wantyou',
#   'say',
#   'would',
#   'wax',
#   'do',
#   'get',
#   'like',
#   'just',
#   'just',
#   'do',
#   'generally',
#   'have',
#   'become',
#   'were',
#   'were',
#   'were',
#   'dont',
#   'got',
#   'do',
#   'do',
#   'wear',
#   'can',
#   'just',
#   'make',
#   'watch',
#   'come',
#   'just',
#   'need',
#   'saw',
#   'get',
#   'look',
#   'just',
#   'hear',
#   'wouldnt',
#   'go',
#   'were',
#   'tried',
#   'get',
#   'get',
#   'get',
#   'get'],
#  'could': ['just',
#   'graph',
#   'just',
#   'just',
#   'have',
#   'do',
#   'do',
#   'ask',
#   'just',
#   'just',
#   'always'],
#  'just': ['eat',
#   'radiating',
#   'go',
#   'cluttering',
#   'go',
#   'fucked',
#   'feel',
#   'right',
#   'and',
#   'crush',
#   'kill',
#   'like',
#   'black',
#   'smell',
#   'had',
#   'had',
#   'gonna',
#   'nag',
#   'stay',
#   'walking',
#   'dehydrates',
#   'blow',
#   'fulfilling',
#   'lets',
#   'put',
#   'felt',
#   'wanted',
#   'sneak',
#   'give',
#   'give',
#   'see',
#   'become',
#   'not',
#   'wanna',
#   'want',
#   'wanna',
#   'wanna',
#   'just',
#   'choke',
#   'waiting',
#   'keep',
#   'try',
#   'had',
#   'swells',
#   'gonna',
#   'travel',
#   'do',
#   'kidding',
#   'gonna',
#   'sopping',
#   'took',
#   'reach',
#   'blow',
#   'i',
#   'scratch',
#   'vacuum',
#   'come',
#   'give',
#   'got',
#   'and',
#   'twerk',
#   'drain',
#   'shit',
#   'when'],
#  'eat': ['like', 'glutenfree', 'all', 'that', 'it', 'snacks', 'a', 'bananas'],
#  'then': ['they',
#   'when',
#   'after',
#   'also',
#   'asian',
#   'if',
#   'afterwards',
#   'all',
#   'it',
#   'i',
#   'you',
#   'you',
#   'your',
#   'if',
#   'it',
#   'you',
#   'on',
#   'i',
#   'at',
#   'at',
#   'a',
#   'i',
#   'resist',
#   'he',
#   'when',
#   'because',
#   'i',
#   'i',
#   'she',
#   'you',
#   'i',
#   'we',
#   'we'],
#  'take': ['a', 'a', 'these', 'a', 'these', 'its'],
#  'sixpack': ['right'],
#  'right': ['they',
#   'they',
#   'thats',
#   'so',
#   'how',
#   'ali',
#   'there',
#   'now',
#   'we',
#   'because',
#   'and',
#   'you',
#   'im',
#   'moment',
#   'turn',
#   'cause',
#   'there',
#   'after',
#   'ive'],
#  'got': ['thatthat',
#   'so',
#   'married',
#   'no',
#   'a',
#   'me',
#   'engaged',
#   'women',
#   'married',
#   'married',
#   'a',
#   'married',
#   'a',
#   'no',
#   'bit',
#   'him',
#   'him',
#   'married',
#   'pregnant'],
#  'thatthat': ['beautiful'],
#  'beautiful': ['inner', 'harvardeducated'],
#  'inner': ['thigh', 'peace', 'evil'],
#  'thigh': ['clearance'],
#  'clearance': ['where'],
#  'where': ['they',
#   'my',
#   'i',
#   'the',
#   'he',
#   'the',
#   'i',
#   'they',
#   'im',
#   'if',
#   'he'],
#  'put': ['their', 'it', 'it', 'it'],
#  'feet': ['together'],
#  'together': ['and', 'you', 'now', 'theyll', 'to', 'when', 'and'],
#  'theres': ['that', 'none', 'this', 'multiple', 'like', 'nothing'],
#  'huge': ['gap', 'unspoken', 'sitdown', 'bear', 'and'],
#  'gap': ['here'],
#  'here': ['with', 'is', 'you'],
#  'light': ['of', 'completely'],
#  'potential': ['just', 'why'],
#  'radiating': ['throughand'],
#  'throughand': ['then'],
#  'go': ['to',
#   'to',
#   'to',
#   'and',
#   'and',
#   'of',
#   'to',
#   'home',
#   'for',
#   'on',
#   'very',
#   'back',
#   'call',
#   'home',
#   'paintballing',
#   'and',
#   'bald',
#   'to',
#   'time',
#   'through',
#   'to'],
#  'sleep': ['they', 'right', 'in'],
#  'insomnia': ['yet'],
#  'yet': ['they', 'they', 'you', 'youre', 'and'],
#  'what': ['its',
#   'that',
#   'your',
#   'that',
#   'it',
#   'love',
#   'the',
#   'i',
#   'happens',
#   'youre',
#   'he',
#   'to',
#   'im',
#   'else',
#   'everybody',
#   'kind',
#   'that',
#   'i',
#   'that',
#   'a'],
#  'ambien': ['or'],
#  'or': ['download',
#   'i',
#   'youre',
#   'you',
#   'for',
#   'something',
#   'whatever',
#   'something'],
#  'download': ['a'],
#  'meditation': ['oasis', 'retreats'],
#  'oasis': ['podcast'],
#  'podcast': ['to'],
#  'calm': ['the'],
#  'chatter': ['of'],
#  'regret': ['and'],
#  'resentment': ['towards', 'especially'],
#  'towards': ['your', 'my', 'him'],
#  'your': ['family',
#   'mind',
#   'is',
#   'wealth',
#   'butt',
#   'mom',
#   'body',
#   'head',
#   'own',
#   'body',
#   'daily',
#   'butt',
#   'butt',
#   'coworkers',
#   'shoes',
#   'butt',
#   'underwear',
#   'shit',
#   'children',
#   'understand',
#   'son',
#   'shame',
#   'inner',
#   'secrets',
#   'just',
#   'man',
#   'thumb',
#   'husband',
#   'lives',
#   'pussy',
#   'hand',
#   'pants',
#   'fingers',
#   'fingers',
#   'first',
#   'ok',
#   'and',
#   'sperm',
#   'face',
#   'pussy',
#   'husband',
#   'leg',
#   'life',
#   'doctors',
#   'body',
#   'nipples'],
#  'family': ['just', 'would', 'funny'],
#  'cluttering': ['your'],
#  'mind': ['they', 'its', 'again'],
#  'whole': ['lives', 'manipulation', 'new', 'foods', 'foods', 'thing'],
#  'lives': ['ahead', 'inside', 'with'],
#  'ahead': ['of'],
#  'them': ['they', 'theyre', 'the', 'nothing', 'once', 'they', 'up'],
#  'hpv': ['yet', 'ok', 'yet', 'because', 'is', 'either', 'will', 'very'],
#  'peace': ['at', 'and', 'sign'],
#  'at': ['night',
#   'home',
#   'this',
#   'the',
#   'the',
#   'golden',
#   'any',
#   'how',
#   'all',
#   'the',
#   'home',
#   'that',
#   'that',
#   'a',
#   'work',
#   'the',
#   'a',
#   'a',
#   'a',
#   'life',
#   'first',
#   'home',
#   'any',
#   'my',
#   'fresh',
#   'some',
#   'my',
#   'work',
#   'him',
#   'his',
#   'his',
#   'extortion'],
#  'night': ['everybody', 'you', 'and', 'everybody'],
#  'has': ['hpv',
#   'it',
#   'it',
#   'hpv',
#   'hosted',
#   'even',
#   'made',
#   'to',
#   'a',
#   'had',
#   'to'],
#  'ok': ['everybody',
#   'come',
#   'im',
#   'that',
#   'so',
#   'you',
#   'a',
#   'i',
#   'because',
#   'you',
#   'so',
#   'are',
#   'cause',
#   'we',
#   'i',
#   'old',
#   'do',
#   'when',
#   'and',
#   'when',
#   'its',
#   'when',
#   'and',
#   'and',
#   'they',
#   'are'],
#  'it': ['its',
#   'if',
#   'yet',
#   'you',
#   'its',
#   'might',
#   'was',
#   'was',
#   'all',
#   'was',
#   'when',
#   'cost',
#   'was',
#   'could',
#   'was',
#   'on',
#   'happened',
#   'happened',
#   'you',
#   'can',
#   'you',
#   'on',
#   'dont',
#   'second',
#   'was',
#   'you',
#   'so',
#   'came',
#   'on',
#   'on',
#   'as',
#   'so',
#   'we',
#   'for',
#   'a',
#   'basically',
#   'and',
#   'backfired',
#   'echo',
#   'in',
#   'in',
#   'in',
#   'up',
#   'up',
#   'interesting',
#   'in',
#   'was',
#   'before',
#   'tonight',
#   'that',
#   'might',
#   'when',
#   'up',
#   'was',
#   'in',
#   'and',
#   'scared',
#   'used',
#   'for',
#   'was',
#   'just',
#   'made',
#   'gets',
#   'tells',
#   'was',
#   'was',
#   'i',
#   'so',
#   'when',
#   'as',
#   'very',
#   'im',
#   'makes',
#   'takes',
#   'also',
#   'easier',
#   'was',
#   'different',
#   'up',
#   'thats',
#   'all',
#   'turns',
#   'how'],
#  'come': ['out', 'in', 'out', 'up', 'out', 'out', 'home', 'with', 'out'],
#  'out': ['already',
#   'of',
#   'there',
#   'of',
#   'they',
#   'and',
#   'they',
#   'at',
#   'about',
#   'down',
#   'of',
#   'of',
#   'of',
#   'first',
#   'that',
#   'of',
#   'its',
#   'like',
#   'of',
#   'of',
#   'when',
#   'at',
#   'they',
#   'about',
#   'and',
#   'yet',
#   'of',
#   'of',
#   'hes'],
#  'already': ['everybody', 'see', 'so', 'see'],
#  'if': ['you',
#   'the',
#   'it',
#   'he',
#   'a',
#   'you',
#   'you',
#   'i',
#   'youre',
#   'you',
#   'you',
#   'you',
#   'i',
#   'you',
#   'its',
#   'im',
#   'i',
#   'he',
#   'you',
#   'i',
#   'i'],
#  'youre': ['a',
#   'in',
#   'busy',
#   'with',
#   'in',
#   'like',
#   'too',
#   'like',
#   'about',
#   'paranoid',
#   'like',
#   'a',
#   'not',
#   'really',
#   'scared',
#   'if',
#   'married',
#   'gonna',
#   'fucking',
#   'the',
#   'bossy',
#   'supposed',
#   'a',
#   'eating',
#   'gonna',
#   'gonna',
#   'in',
#   'youll',
#   'having',
#   'gonna',
#   'in'],
#  'fucking': ['loser', 'housewife', 'different', 'baby', 'baby'],
#  'loser': ['all'],
#  'all': ['right',
#   'about',
#   'of',
#   'your',
#   'came',
#   'required',
#   'because',
#   'this',
#   'right',
#   'his',
#   'of',
#   'of',
#   'the',
#   'up',
#   'fucked',
#   'red',
#   'you',
#   'that',
#   'of',
#   'over',
#   'with',
#   'riled',
#   'day',
#   'these',
#   'day',
#   'over',
#   'day',
#   'the',
#   'sorts',
#   'of',
#   'your',
#   'hes',
#   'squirmy',
#   'right',
#   'the',
#   'the',
#   'my',
#   'these',
#   'of',
#   'know',
#   'of',
#   'the',
#   'the',
#   'day',
#   'you',
#   'good',
#   'of',
#   'the',
#   'backed',
#   'of',
#   'your',
#   'this',
#   'back',
#   'wet',
#   'wet',
#   'my',
#   'off',
#   'right',
#   'rights'],
#  'thats': ['what',
#   'gonna',
#   'right',
#   'what',
#   'not',
#   'where',
#   'right',
#   'like',
#   'how',
#   'how',
#   'not',
#   'right',
#   'gonna',
#   'why',
#   'the',
#   'when',
#   'not',
#   'hilarious',
#   'the',
#   'the',
#   'cool',
#   'not',
#   'so',
#   'thats',
#   'shit',
#   'right',
#   'so',
#   'like',
#   'my',
#   'why',
#   'a',
#   'enough',
#   'the',
#   'not'],
#  'says': ['about', 'boo', 'please', 'to'],
#  'about': ['you',
#   'how',
#   'the',
#   'him',
#   'a',
#   'vietnamese',
#   'it',
#   'supporting',
#   'our',
#   'how',
#   'those',
#   'housewives',
#   'to',
#   'the',
#   'money',
#   'anal',
#   'is',
#   'im',
#   'that',
#   'is',
#   'to',
#   'to',
#   'it',
#   'giving',
#   'childbirth',
#   'all',
#   'kanye',
#   'growing',
#   'privacy'],
#  'lot': ['of',
#   'this',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'i',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'men': ['dont', 'its', 'are', 'are', 'no', 'we', 'as'],
#  'undetectable': ['in'],
#  'really': ['fucked',
#   'im',
#   'its',
#   'work',
#   'meant',
#   'you',
#   'scared',
#   'i',
#   'am',
#   'take',
#   'am',
#   'hot'],
#  'fucked': ['up', 'a', 'up', 'so'],
#  'ghost': ['that'],
#  'inside': ['mens', 'horrible', 'i', 'of'],
#  'mens': ['bodies'],
#  'bodies': ['and', 'my'],
#  'boo': ['in'],
#  'womens': ['bodies', 'intuition'],
#  'doctor': ['told', 'right', 'your', 'says', 'appointments'],
#  'told': ['me', 'her', 'you', 'my', 'her'],
#  'one': ['of', 'of', 'of', 'of', 'person', 'i', 'of', 'she', 'of', 'who'],
#  'two': ['strains', 'homeless', 'days', 'latina', 'sacks', 'weeks'],
#  'strains': ['of'],
#  'either': ['i', 'im'],
#  'kind': ['thats', 'where', 'of', 'of', 'of', 'of'],
#  'turn': ['into', 'this', 'this', 'into', 'signal', 'i', 'upside'],
#  'cervical': ['cancer'],
#  'cancer': ['or'],
#  'body': ['will', 'is', 'hair', 'is', 'odor', 'was', 'when', 'where'],
#  'will': ['heal',
#   'also',
#   'also',
#   'you',
#   'always',
#   'be',
#   'have',
#   'commend',
#   'not'],
#  'heal': ['itself', 'from'],
#  'itself': ['very'],
#  'helpful': ['this'],
#  'basically': ['either', 'just', 'like'],
#  'die': ['or', 'and', 'dont', 'but', 'we', 'especially', 'were', 'why'],
#  'presence': ['of'],
#  'wolverine': ['bitches'],
#  'bitches': ['well', 'i'],
#  'well': ['find', 'with', 'i', 'see', 'asian'],
#  'find': ['outum', 'a', 'ways', 'a', 'it'],
#  'outum': ['i'],
#  'also': ['tell',
#   'disappear',
#   'got',
#   'last',
#   'hes',
#   'dont',
#   'decided',
#   'takes'],
#  'kindle': ['is'],
#  'turning': ['into', 'into'],
#  'selfhelp': ['library'],
#  'library': ['im'],
#  'not': ['interested',
#   'happy',
#   'trying',
#   'the',
#   'kissing',
#   'ask',
#   'authentic',
#   'recognize',
#   'doing',
#   'a',
#   'even',
#   'have',
#   'be',
#   'dieting',
#   'scared',
#   'as',
#   'the',
#   'again',
#   'rush',
#   'trying',
#   'my',
#   'technically',
#   'as',
#   'ok',
#   'fuckin',
#   'because',
#   'doing',
#   'there',
#   'gonna',
#   'like',
#   'the',
#   'be'],
#  'interested': ['in', 'in'],
#  'books': ['like', 'history'],
#  'fifty': ['shades'],
#  'shades': ['of'],
#  'grey': ['ok'],
#  'lifechanging': ['magic'],
#  'magic': ['of'],
#  'tidying': ['up'],
#  'how': ['to',
#   'can',
#   'can',
#   'proposals',
#   'did',
#   'rotten',
#   'offstage',
#   'we',
#   'to',
#   'much',
#   'invincible',
#   'a',
#   'theres',
#   'it',
#   'did',
#   'did'],
#  'declutter': ['my'],
#  'home': ['to', 'in', 'and', 'all', 'and', 'chapping', 'and', 'together'],
#  'achieve': ['inner', 'my'],
#  'optimum': ['level', 'level'],
#  'level': ['of', 'of'],
#  'success': ['thats'],
#  'around': ['im', 'help', 'together', 'all', 'they', 'to', 'the', 'by'],
#  'horrible': ['person', 'but', 'toilet'],
#  'person': ['im', 'you', 'for'],
#  'happy': ['with'],
#  'am': ['how', 'seven', 'imma', 'already', 'not', 'mad'],
#  'help': ['me', 'mei', 'her', 'you', 'as'],
#  'tony': ['robbins'],
#  'robbins': ['help'],
#  'mei': ['have'],
#  'problem': ['which', 'because'],
#  'which': ['im',
#   'is',
#   'a',
#   'means',
#   'would',
#   'is',
#   'means',
#   'their',
#   'is',
#   'is',
#   'hes',
#   'i',
#   'is',
#   'is',
#   'is',
#   'means',
#   'subsequently'],
#  'hoping': ['is', 'that'],
#  'center': ['of'],
#  'other': ['problems', 'homeless', 'because', 'day', 'you', 'shitty'],
#  'problems': ['im'],
#  'goes': ['away', 'down'],
#  'away': ['the', 'anything', 'from', 'a', 'at'],
#  'disappear': ['i', 'thats', 'and'],
#  'mom': ['is', 'it', 'got', 'my', 'is', 'i', 'is', 'shes', 'people'],
#  'third': ['world', 'grade', 'world'],
#  'world': ['country', 'it', 'with', 'country'],
#  'country': ['and', 'and', 'and'],
#  'she': ['taught',
#   'refused',
# ...
#  'city': ['in'],
#  'america': ['and'],
#  'yoko': ['ono'],
#  'ono': ['factory'],
#  'factory': ['its'],
#  'too': ['much',
#   'nice',
#   'him',
#   'we',
#   'but',
#   'old',
#   'late',
#   'stupid',
#   'they',
#   'funky'],
#  'whats': ['wrong', 'gonna', 'wrong', 'crackin', 'in'],
#  'wrong': ['with', 'with'],
#  'being': ['with', 'the', 'courageous'],
#  'feel': ['very',
#   'very',
#   'like',
#   'more',
#   'like',
#   'like',
#   'rushed',
#   'like',
#   'so',
#   'bad'],
#  'picturesque': ['when'],
#  'wes': ['anderson'],
#  'anderson': ['movie'],
#  'movie': ['or', 'ok', 'reviews', 'transcripts'],
#  'teach': ['you'],
#  'cool': ['stuff', 'stuff', 'until'],
#  'stuff': ['like', 'like'],
#  'voting': ['and'],
#  'recycling': ['and'],
#  'disturbing': ['documentaries'],
#  'documentaries': ['they'],
#  'introduce': ['you'],
#  'hot': ['hookin', 'you', 'you', 'forever'],
#  'hookin': ['up'],
#  'mean': ['nothing', 'were', 'that', 'pay'],
#  'nothing': ['makes', 'they', 'for'],
#  'makes': ['me', 'me', 'sense'],
#  'more': ['powerful',
#   'like',
#   'options',
#   'doo',
#   'money',
#   'successful',
#   'to',
#   'women',
#   'handsome',
#   'dave',
#   'transcripts'],
#  'powerful': ['than'],
#  'eats': ['my'],
#  'pussy': ['oh', 'needs', 'is', 'was', 'to'],
#  'absorbing': ['all'],
#  'privilege': ['and'],
#  'entitlement': ['you'],
#  'through': ['the', 'southeast', 'and', 'a', 'it', 'a'],
#  'money': ['hole', 'they', 'you', 'if', 'you', 'paid'],
#  'hole': ['and', 'its', 'feels', 'and'],
#  'vulnerable': ['down'],
#  'down': ['there',
#   'its',
#   'i',
#   'i',
#   'there',
#   'your',
#   'immediately',
#   'in',
#   'so',
#   'people',
#   'with'],
#  'crush': ['your', 'those', 'while'],
#  'head': ['at', 'first', 'shredding', 'and', 'for'],
#  'moment': ['white', 'to', 'you'],
#  'kill': ['you', 'me'],
#  'brains': ['colonize'],
#  'colonize': ['the'],
#  'colonizer': ['you'],
#  'knowbut': ['i'],
#  'think': ['that',
#   'my',
#   'feminism',
#   'we',
#   'its',
#   'of',
#   'about',
#   'thats',
#   'so',
#   'im'],
#  'marriage': ['it', 'i', 'because'],
#  'nice': ['to', 'we'],
#  'somebody': ['of', 'closes', 'closes'],
#  'own': ['race', 'goddamn'],
#  'race': ['the'],
#  'advantage': ['is'],
#  'racist': ['together'],
#  'say': ['whatever', 'to', 'you', 'you', 'be'],
#  'whatever': ['you', 'and', 'they', 'you', 'the'],
#  'explain': ['shit'],
#  'halffilipino': ['halfjapanese', 'and'],
#  'halfjapanese': ['im', 'and'],
#  'halfchinese': ['and', 'and'],
#  'halfvietnamese': ['and', 'so'],
#  'spend': ['percent'],
#  'percent': ['of', 'of', 'spoken'],
#  'our': ['time',
#   'first',
#   'buddha',
#   'careers',
#   'job',
#   'day',
#   'society',
#   'first',
#   'weekly',
#   'archive'],
#  'shitting': ['on'],
#  'korean': ['people'],
#  'amazing': ['its'],
#  'love': ['is', 'to', 'it', 'my', 'it', 'of'],
#  'built': ['on'],
#  'knowmy': ['last', 'husband'],
#  'boyfriend': ['was', 'because'],
#  'cuban': ['and'],
#  'would': ['shit',
#   'double',
#   'not',
#   'have',
#   'i',
#   'crash',
#   'simultaneously',
#   'explode',
#   'be',
#   'be',
#   'inevitably',
#   'only',
#   'be',
#   'come',
#   'just',
#   'close',
#   'jump',
#   'just',
#   'turn',
#   'just',
#   'talk'],
#  'mexican': ['people', 'asianamerican', 'friends'],
#  'guys': ['arent', 'know', 'about', 'need', 'had', 'can', 'i', 'doin'],
#  'arent': ['mexican'],
#  'underrated': ['i'],
#  'sexiest': ['asian', 'they'],
#  'hair': ['from'],
#  'neck': ['down', 'and'],
#  'making': ['love'],
#  'dolphin': ['oh'],
#  'smooth': ['just'],
#  'slip': ['and'],
#  'slide': ['just'],
#  'black': ['fish', 'dont', 'friends', 'friends'],
#  'fish': ['tilikum'],
#  'tilikum': ['all'],
#  'bed': ['every', 'women'],
#  'every': ['night',
#   'day',
#   'single',
#   'day',
#   'day',
#   'day',
#   'day',
#   'time',
#   'single',
#   'time',
#   'man'],
#  'oohwee': ['you'],
#  'mess': ['with', 'theres'],
#  'jewish': ['dude', 'male'],
#  'afterwards': ['its', 'the', 'and', 'and', 'i', 'to'],
#  'red': ['and', 'light'],
#  'inflamed': ['and'],
#  'ask': ['to', 'for'],
#  'exfoliated': ['today'],
#  'today': ['this'],
#  'jdate': ['more'],
#  'loofah': ['date'],
#  'thanks': ['for'],
#  'rug': ['burn'],
#  'burn': ['avi', 'out'],
#  'avi': ['and'],
#  'odor': ['none'],
#  'none': ['they', 'of'],
#  'smell': ['like', 'my', 'my', 'my', 'my', 'my', 'my'],
#  'responsibility': ['thats', 'and'],
#  'umami': ['flavor'],
#  'flavor': ['comes'],
#  'comes': ['fromi', 'out', 'out', 'out', 'to'],
#  'fromi': ['think'],
#  'unspoken': ['understanding'],
#  'understanding': ['uh'],
#  'between': ['each', 'your'],
#  'each': ['other', 'other'],
#  'both': ['halffancy', 'total', 'are'],
#  'halffancy': ['asian'],
#  'halfjungle': ['asian'],
#  'difference': ['the'],
#  'fancy': ['asians', 'things'],
#  'asians': ['are', 'host', 'we'],
#  'chinese': ['the', 'scrolls', 'ladies', 'ladies'],
#  'japanese': ['they'],
#  'host': ['olympics', 'diseases'],
#  'olympics': ['jungle'],
#  'jungle': ['asians'],
#  'diseases': ['its'],
#  'different': ['but', 'person', 'holes', 'people', 'its', 'and'],
#  'east': ['coast'],
#  'coast': ['going'],
#  'private': ['school', 'school', 'school'],
#  'playing': ['lacrosse', 'chess', 'dumb', 'candy'],
#  'lacrosse': ['uh'],
#  'learning': ['latin'],
#  'latin': ['and'],
#  'chess': ['and'],
#  'rugby': ['he'],
#  'filipino': ['carlton'],
#  'carlton': ['ok'],
#  'didnt': ['know', 'think', 'know', 'know'],
#  'vietnamese': ['people', 'i'],
#  'dates': ['he'],
#  'took': ['me', 'it', 'me'],
#  'restaurant': ['on', 'deaf'],
#  'west': ['side', 'the'],
#  'side': ['of', 'from', 'effect'],
#  'los': ['angeles', 'angeles'],
#  'angeles': ['called', 'an'],
#  'called': ['pho', 'lean', 'bossy'],
#  'pho': ['show'],
#  'authentic': ['vietnamese', 'ok'],
#  'read': ['about', 'more', 'more'],
#  'yelp': ['i'],
#  'name': ['cause', 'transcriptdave'],
#  'number': ['in'],
#  'second': ['of', 'chance'],
#  'bathroom': ['if', 'would'],
#  'legit': ['the'],
#  'double': ['as', 'standard'],
#  'supply': ['closet'],
#  'closet': ['when'],
#  'gallons': ['of'],
#  'bleach': ['an'],
#  'atm': ['machine'],
#  'machine': ['and'],
#  'grandma': ['with', 'youre'],
#  'glaucoma': ['napping'],
#  'napping': ['in'],
#  'corner': ['and'],
#  'wait': ['staff', 'to'],
#  'staff': ['here', 'and'],
#  'leave': ['this', 'without', 'you', 'a', 'this'],
#  'deaf': ['and'],
#  'emotionally': ['abusedi'],
#  'abusedi': ['grew'],
#  'total': ['like'],
#  'big': ['hippies', 'fantasy', 'impact', 'they', 'like'],
#  'hippies': ['too', 'id'],
#  'backpack': ['through'],
#  'southeast': ['asia'],
#  'asia': ['we'],
#  'yoga': ['we'],
#  'ayahuasca': ['ceremonies'],
#  'ceremonies': ['we'],
#  'silent': ['meditation'],
#  'retreats': ['thats'],
#  'pay': ['to', 'for'],
#  'shut': ['up', 'the', 'up', 'the'],
#  'weekend': ['we'],
#  'glutenfree': ['which'],
#  'means': ['we', 'i', 'the', 'ok', 'youre'],
#  'bread': ['that', 'thats', 'thats'],
#  'tastes': ['like', 'when'],
#  'freerange': ['chewbacca'],
#  'chewbacca': ['we'],
#  'lesbian': ['bread'],
#  'thousand': ['percent'],
#  'daily': ['fiber', 'basis', 'basis'],
#  'fiber': ['and'],
#  'spoken': ['word'],
#  'word': ['poetry', 'bossy', 'bossy'],
#  'poetry': ['when'],
#  'queef': ['a'],
#  'shitty': ['poem', 'dads', 'mom'],
#  'poem': ['about'],
#  'supporting': ['caitlyn'],
#  'caitlyn': ['jenner'],
#  'jenner': ['or'],
#  'funny': ['right', 'man'],
#  'sometimes': ['all'],
#  'hippydippy': ['shit'],
#  'doing': ['an', 'anything', 'jack', 'itnow'],
#  'impression': ['of'],
#  'scrolls': ['up'],
#  'wall': ['and', 'that'],
#  'neither': ['of'],
#  'us': ['know', 'and', 'to'],
#  'seems': ['to', 'to'],
#  'buddha': ['piggy'],
#  'piggy': ['bank'],
#  'bank': ['from'],
#  'pier': ['imports'],
#  'imports': ['that'],
#  'providing': ['some'],
#  'some': ['good', 'its', 'risk', 'useful', 'lame', 'point', 'of'],
#  'good': ['feng', 'we', 'in', 'night'],
#  'feng': ['shui'],
#  'shui': ['for'],
#  'househim': ['and'],
#  'four': ['years', 'days'],
#  'years': ['and', 'and', 'ive', 'old', 'old'],
#  'sneaking': ['suspicion'],
#  'suspicion': ['that'],
#  'propose': ['because', 'to'],
#  'pressuring': ['him'],
#  'wacky': ['womens'],
#  'intuition': ['thats'],
#  'proposals': ['really'],
#  'work': ['ok',
#   'anymore',
#   'anymore',
#   'anymore',
#   'when',
#   'at',
#   'because',
#   'on',
#   'anymore',
#   'anymoreim',
#   'i',
#   'we'],
#  'incept': ['the'],
#  'idea': ['into'],
#  'mans': ['head', 'eye'],
#  'passively': ['and'],
#  'doesnt': ['get', 'see', 'have', 'have', 'believe'],
#  'message': ['extremely'],
#  'extremely': ['aggressively', 'itchy'],
#  'aggressively': ['you'],
#  'threaten': ['to'],
#  'without': ['ever'],
#  'actually': ['leaving'],
#  'leaving': ['because'],
#  'old': ['and', 'as', 'chinese', 'chinese', 'asian', 'and', 'when'],
#  'late': ['to'],
#  'new': ['man', 'world'],
#  'start': ['the', 'all', 'watching'],
#  'manipulation': ['cycle'],
#  'cycle': ['all'],
#  'again': ['so', 'and', 'its', 'i', 'but', 'because'],
#  'stick': ['with', 'your'],
#  'focus': ['on'],
#  'trapping': ['this'],
#  'nag': ['the'],
#  'outta': ['him', 'nowhere'],
#  'becomes': ['weak'],
#  'weak': ['and'],
#  'caves': ['in'],
#  'gets': ['fed', 'very'],
#  'fed': ['up'],
#  'fine': ['will', 'by', 'on'],
#  'marry': ['me', 'him'],
#  'always': ['like', 'very', 'feel', 'catch', 'means', 'tell', 'wantedim'],
#  'proposed': ['it'],
#  'nowhere': ['and', 'and'],
#  'look': ['he',
#   'at',
#   'at',
#   'in',
#   'on',
#   'like',
#   'me',
#   'you',
#   'forward',
#   'like',
#   'like'],
#  'exact': ['ring'],
#  'ring': ['i'],
#  'wanted': ['how', 'to', 'him'],
#  'maybe': ['he', 'youll', 'because'],
#  'pinterest': ['page', 'page'],
#  'page': ['or', 'hes'],
#  'sent': ['to'],
#  'best': ['friend', 'you'],
#  'friend': ['that'],
#  'send': ['to'],
#  'pinterested': ['in'],
#  'engaged': ['on'],
#  'saturday': ['i'],
#  'bought': ['my', 'me', 'our'],
#  'dress': ['the'],
#  'following': ['tuesday'],
#  'tuesday': ['because'],
#  'tried': ['it', 'to', 'to'],
#  'ready': ['i'],
#  'ripe': ['i'],
#  'rotten': ['i', 'i'],
#  'banana': ['bread'],
#  'waspeople': ['are'],
#  'surprised': ['at'],
#  'offstage': ['with'],
#  'completely': ['different', 'im'],
#  'recognize': ['my', 'your'],
#  'personality': ['at'],
#  'soft': ['and', 'serve'],
#  'nurturing': ['and'],
#  'domestic': ['weve'],
#  'weve': ['been'],
#  'ive': ['packed', 'been', 'been', 'asked', 'picked', 'been'],
#  'packed': ['his'],
#  'lunch': ['every'],
#  'single': ['day', 'night'],
#  'hed': ['become'],
#  'become': ['dependent', 'the', 'a', 'this', 'youre', 'some'],
#  'dependent': ['on'],
#  'graduated': ['from', 'from'],
#  'feed': ['him'],
#  'goodness': ['of'],
#  'heart': ['i'],
#  'investment': ['in'],
#  'financial': ['future'],
#  'reading': ['that'],
#  'book': ['by', 'that', 'is'],
#  'sheryl': ['sandberg'],
#  'sandberg': ['shes', 'that'],
#  'shes': ['the',
#   'not',
#   'retiredi',
#   'waiting',
#   'timing',
#   'busy',
#   'got',
#   'from'],
#  'coo': ['of'],
#  'facebook': ['and'],
#  'wrote': ['that', 'lean'],
#  'riled': ['up'],
#  'careers': ['talking'],
#  'talking': ['about', 'about', 'about'],
#  'should': ['challenge', 'not', 'never'],
#  'challenge': ['ourselves'],
#  'ourselves': ['to'],
#  'sit': ['at'],
#  'table': ['and', 'and', 'i'],
#  'rise': ['to', 'to'],
#  'top': ['and'],
#  'lean': ['in', 'in', 'in'],
#  'lie': ['down', 'the'],
#  'want': ['to',
#   'they',
#   'their',
#   'to',
#   'my',
#   'noah',
#   'i',
#   'for',
#   'to',
#   'your',
#   'to'],
#  'job': ['used', 'we', 'at', 'most'],
#  'used': ['to', 'to', 'it'],
#  'smart': ['thing'],
#  'continue': ['playing'],
#  'dumb': ['for', 'women'],
#  'century': ['and', 'more'],
#  'guess': ['we', 'who'],
#  'stay': ['at', 'thats'],
#  'snacks': ['and'],
#  'watch': ['ellen', 'property', 'when', 'the'],
#  'ellen': ['cause'],
#  'stupid': ['to'],
#  'real': ['responsibility', 'boss', 'miracle'],
#  'bitch': ['shut', 'is', 'had'],
#  'ruined': ['it'],
#  'expected': ['to'],
#  'hear': ['the', 'my', 'that'],
#  'phrase': ['doubleincome', 'black'],
#  'doubleincome': ['household'],
#  'household': ['i'],
#  'upset': ['with'],
#  'comments': ['and'],
#  'options': ['now', 'when'],
#  'free': ['unscheduled', 'to', 'activity'],
#  'unscheduled': ['unsupervised'],
#  'unsupervised': ['and'],
#  'most': ['importantly', 'strongheaded', 'in', 'likely', 'of', 'of', 'women'],
#  'importantly': ['sponsored'],
#  'sponsored': ['do'],
#  'shittier': ['food'],
#  'food': ['tastes'],
#  'earn': ['ita'],
#  'ita': ['lot'],
#  'walk': ['around'],
#  'theyll': ['get', 'be', 'get', 'be'],
#  'judgmental': ['about'],
#  'housewives': ['that', 'they', 'get', 'they', 'are', 'they'],
#  'street': ['and'],
#  'housewife': ['not', 'just', 'shes', 'financially'],
#  'walking': ['around', 'like'],
#  'massages': ['in'],
#  'lululemon': ['pants'],
#  'pants': ['im', 'at'],
#  'genius': ['shes'],
#  'retiredi': ['do'],
#  'write': ['for'],
#  'fresh': ['off', 'off'],
#  'boat': ['on', 'i'],
#  'abc': ['yeah'],
#  'great': ['show', 'writing', 'dad'],
#  'coworkers': ['its', 'gonna', 'blow', 'blow', 'and'],
#  'writing': ['staff', 'job'],
#  'terms': ['of', 'of'],
#  'jobs': ['its'],
#  'still': ['gotta', 'here'],
#  'office': ['every', 'every', 'housewives', 'toilet'],
#  'house': ['skin', 'hey'],
#  'skin': ['to', 'every'],
#  'seat': ['they'],
#  'use': ['that', 'that', 'the', 'contact'],
#  'toilet': ['paper',
#   'paper',
#   'paper',
#   'paper',
#   'paper',
#   'and',
#   'i',
#   'the',
#   'and'],
#  'paper': ['cover', 'that', 'that', 'thats', 'two'],
#  'cover': ['they'],
#  'times': ['a'],
#  'sadass': ['meal'],
#  'meal': ['they'],
#  'oneply': ['toilet'],
#  'purposely': ['make'],
#  'difficult': ['to'],
#  'pull': ['out'],
#  'try': ['to', 'to', 'to', 'to', 'to'],
#  'ration': ['me'],
#  'communist': ['toilet'],
#  'effective': ['it'],
#  'dehydrates': ['your'],
#  'wiping': ['your', 'at', 'and'],
#  'desert': ['i'],
#  'literally': ['spat', 'trying'],
#  'spat': ['on'],
#  'days': ['ago', 'out', 'he', 'i'],
#  'ago': ['to'],
#  'macgyver': ['baby'],
#  'wipe': ['to'],
#  'moisten': ['it'],
#  'backfired': ['cause'],
#  'fingers': ['broke',
#   'oh',
#   'afterwards',
#   'when',
#   'housewives',
#   'when',
#   'when',
#   'nature',
#   'are',
#   'like'],
#  'broke': ['through', 'up'],
#  'digitally': ['stimulated'],
#  'stimulated': ['more'],
#  'doo': ['doo',
#   'to',
#   'doo',
#   'all',
#   'doo',
#   'comes',
#   'doo',
#   'comes',
#   'doo',
#   'on'],
#  'finish': ['wiping', 'wiping', 'i', 'its'],
#  'rushed': ['cause'],
#  'paranoid': ['that'],
#  'shoes': ['underneath', 'its'],
#  'underneath': ['the', 'the'],
#  'stall': ['and'],
#  'courtneys': ['listening'],
#  'listening': ['shes'],
#  'waiting': ['shes', 'for'],
#  'timing': ['me'],
#  'hurry': ['hurry', 'hurry', 'and', 'the'],
#  'feels': ['caked'],
#  'caked': ['in'],
#  'long': ['and', 'they'],
#  'dare': ['scratch', 'you'],
#  'scratch': ['yourself', 'on', 'myself', 'and', 'sniff', 'whats', 'yourself'],
#  'yourself': ['your', 'do', 'all'],
#  'underwear': ['at', 'and'],
#  'end': ['of'],
#  'looks': ['like'],
#  'goonies': ['housewives'],
#  'muffle': ['their'],
#  'worry': ['about', 'cause'],
#  'velocity': ['with'],
#  'squeeze': ['the'],
#  'cheeks': ['together'],
#  'sure': ['that', 'that', 'all'],
#  'slow': ['and'],
#  'steady': ['pace'],
#  'pace': ['so'],
#  'unpredictable': ['noise'],
#  'noise': ['suddenly'],
#  'suddenly': ['escapes'],
#  'escapes': ['and'],
#  'brings': ['you'],
#  'deep': ['deep', 'shame'],
#  'shame': ['housewives', 'your', 'theyre'],
#  'blow': ['ass', 'ass', 'ass', 'a'],
#  'echo': ['and'],
#  'reverberate': ['to'],
#  'ends': ['of'],
#  'hallways': ['while'],
#  'while': ['watching', 'it', 'i', 'i'],
#  'watching': ['as', 'porn', 'porn'],
#  'netflix': ['on'],
#  'ipad': ['as'],
#  'boring': ['repressed', 'and'],
#  'repressed': ['shits'],
#  'shits': ['they'],
#  'listen': ['to'],
#  'podcasts': ['planet'],
#  'planet': ['money'],
#  'wantyou': ['know'],
#  'distracting': ['for'],
#  'lose': ['respect'],
#  'respect': ['for', 'you', 'me'],
#  'holds': ['any', 'the'],
#  'sort': ['of'],
#  'credence': ['i'],
#  'heard': ['one', 'you'],
#  'nerve': ['to'],
#  'bananas': ['i'],
#  'green': ['ballet'],
#  'ballet': ['flats'],
#  'flats': ['i'],
#  'togethermy': ['fatherinlaw'],
#  'fatherinlaw': ['had'],
#  'sitdown': ['with'],
#  'recently': ['um', 'we'],
#  'um': ['and', 'yeah'],
#  'talk': ['to', 'cause', 'im', 'about'],
#  'provide': ['your'],
#  'children': ['with', 'to', 'to'],
#  'same': ['kind', 'when'],
#  'privileged': ['childhood'],
#  'childhood': ['that'],
#  'telling': ['me'],
#  'conversation': ['you'],
#  'son': ['that', 'for'],
#  'understand': ['that'],
#  'earning': ['potential'],
#  'else': ['would', 'i', 'has', 'do'],
#  'choose': ['to'],
#  'rest': ['of', 'of'],
#  'chose': ['to'],
#  'promise': ['of'],
#  'early': ['retirement', 'and'],
#  'retirement': ['and'],
#  'said': ['i', 'to', 'but'],
#  'meant': ['was'],
#  'dieting': ['anymore'],
#  'since': ['i', 'thats'],
#  'eating': ['fried', 'mango'],
#  'fried': ['chicken'],
#  ...}

# %%
joe_dict = markov_chain(joe_text)
joe_dict
# Out:
# {'': ['joe'],
#  'joe': ['rogan', 'rogan', 'roganwhat'],
#  'rogan': ['triggered', 'triggered', 'explores', 'standup'],
#  'triggered': ['transcript', '–'],
#  'transcript': ['scraps', 'august'],
#  'scraps': ['from', 'from'],
#  'from': ['the',
#   'why',
#   'bruce',
#   'the',
#   'the',
#   'her',
#   'her',
#   'the',
#   'around',
#   'them',
#   'but',
#   'today',
#   'i',
#   'the',
#   'crabs',
#   'you',
#   'it',
#   'tight',
#   'the'],
#  'the': ['loft',
#   'fck',
#   'move',
#   'people',
#   'fck',
#   'other',
#   'fck',
#   'problem',
#   'same',
#   'pot',
#   'gummy',
#   'leg',
#   'leg',
#   'fck',
#   'scary',
#   'thing',
#   'problems',
#   'boat',
#   'earth',
#   'boats',
#   'suns',
#   'water',
#   'water',
#   'water',
#   'water',
#   'clouds',
#   'bottom',
#   'time',
#   'words',
#   'foods',
#   'waters',
#   'same',
#   'other',
#   'same',
#   'same',
#   'way',
#   'word',
#   'case',
#   'same',
#   'secret',
#   'middle',
#   'ocean',
#   'problem',
#   'people',
#   'weirdest',
#   'most',
#   'weirdest',
#   'shit',
#   'type',
#   'world',
#   'best',
#   'fck',
#   'white',
#   'fcking',
#   'we',
#   'first',
#   'white',
#   'first',
#   'front',
#   'olympics',
#   'fcking',
#   'white',
#   'white',
#   'wrong',
#   'world',
#   'park',
#   'same',
#   'white',
#   'world',
#   'fck',
#   'door',
#   'flu',
#   'fck',
#   'guy',
#   'front',
#   'door',
#   'front',
#   'fck',
#   'front',
#   'whole',
#   'whole',
#   'breakin',
#   'white',
#   'real',
#   'strings',
#   'story',
#   'real',
#   'person',
#   'white',
#   'governments',
#   'governments',
#   'time',
#   'white',
#   'map',
#   'white',
#   'white',
#   'white',
#   'white',
#   'only',
#   'white',
#   'white',
#   'grass',
#   'guy',
#   'white',
#   'government',
#   'last',
#   'last',
#   'front',
#   'ground',
#   'hall',
#   'first',
#   'middle',
#   'night',
#   'people',
#   'fck',
#   'guy',
#   'white',
#   'president',
#   'moment',
#   'fck',
#   'fck',
#   'hallway',
#   'greatest',
#   'background',
#   'white',
#   'original',
#   'and',
#   'background',
#   'national',
#   'notifications',
#   'dick',
#   'hands',
#   'mens',
#   'noble',
#   'world',
#   'four',
#   'fck',
#   'fck',
#   'fcking',
#   'car',
#   'car',
#   'fck',
#   'dumbest',
#   'ocean',
#   'fck',
#   'worlds',
#   'salt',
#   'water',
#   'dirty',
#   'launch',
#   'middle',
#   'country',
#   'heavens',
#   'sky',
#   'tip',
#   'cosmos',
#   'church',
#   'street',
#   'fcks',
#   'walls',
#   'face',
#   'earth',
#   'one',
#   'mormons',
#   'size',
#   'fck',
#   'government',
#   'united',
#   'government',
#   'united',
#   'fck',
#   'fck',
#   'meanwhile',
#   'mormons',
#   'guys',
#   'book',
#   'mormons',
#   'mormons',
#   'playbill',
#   'chin',
#   'fck',
#   'one',
#   'most',
#   'world',
#   'reaction',
#   'whole',
#   'whole',
#   'scariest',
#   'la',
#   'pictures',
#   'balance',
#   'pictures',
#   'building',
#   'east',
#   'stubborn',
#   'smart',
#   'way',
#   'biggest',
#   'worlds',
#   'sand',
#   'biggest',
#   'reasons',
#   'best',
#   'spots',
#   'people',
#   'weather',
#   'winter',
#   'morning',
#   'same',
#   'people',
#   'best',
#   'way',
#   'wild',
#   'world',
#   'fear',
#   'rest',
#   'fcking',
#   'rule',
#   'first',
#   'russians',
#   'russians',
#   'children',
#   'children',
#   'people',
#   'worst',
#   'fact',
#   'youngest',
#   'things',
#   'first',
#   'last',
#   'kids',
#   'fck',
#   'boat',
#   'boat',
#   'kids',
#   'dark',
#   'only',
#   'kid',
#   'forest',
#   'teacher',
#   'kids',
#   'fck',
#   'fck',
#   'day',
#   'chimney',
#   'fck',
#   'house',
#   'big',
#   'big',
#   'problem',
#   'hollow',
#   'feathers',
#   'air',
#   'air',
#   'trees',
#   'wind',
#   'birds',
#   'fat',
#   'little',
#   'most',
#   'guy',
#   'only',
#   'fcking',
#   'only',
#   'world',
#   'most',
#   'opposite',
#   'salmon',
#   'eagle',
#   'universe',
#   'mouth',
#   'only',
#   'other',
#   'kids',
#   'kids',
#   'yeah',
#   'dude',
#   'earths',
#   'way',
#   'strictest',
#   'bible',
#   'earth',
#   'earth',
#   'average',
#   'earth',
#   'earth',
#   'people',
#   'we',
#   'wrong',
#   'really',
#   'world',
#   'fck',
#   'who',
#   'fck',
#   'shit',
#   'dead',
#   'first',
#   'process',
#   'insane',
#   'words',
#   'meanest',
#   'youtube',
#   'world',
#   'world',
#   'greatest',
#   'old',
#   'fck',
#   'world',
#   'stuff',
#   'happiest',
#   'time',
#   'rock',
#   'water',
#   'fence',
#   'switch',
#   'fck',
#   'woods',
#   'characters',
#   'movies',
#   'people',
#   'people',
#   'worst',
#   'worst',
#   'fck',
#   'interactions',
#   'people',
#   'take',
#   'wrong',
#   'color',
#   'leaf',
#   'kardashians',
#   'middle',
#   'night',
#   'plot',
#   'whole',
#   'worlds',
#   'bed',
#   'edge',
#   'bed',
#   'gender',
#   'cover',
#   'cover',
#   'covers',
#   'fck',
#   'midterm',
#   'hilarious',
#   'record',
#   'highest',
#   'loft'],
#  'loft': ['skip', 'all'],
#  'skip': ['to'],
#  'to': ['content',
#   'be',
#   'people',
#   'debbie',
#   'slow',
#   'do',
#   'peoplei',
#   'steal',
#   'prove',
#   'dolphinsthis',
#   'figure',
#   'live',
#   'the',
#   'me',
#   'a',
#   'water',
#   'president',
#   'president',
#   'be',
#   'write',
#   'get',
#   'assholes',
#   'get',
#   'say',
#   'save',
#   'say',
#   'sound',
#   'fck',
#   'fck',
#   'see',
#   'fck',
#   'morph',
#   'figure',
#   'fit',
#   'guard',
#   'do',
#   'go',
#   'die',
#   'ask',
#   'die',
#   'the',
#   'the',
#   'die',
#   'go',
#   'fcking',
#   'say',
#   'kill',
#   'see',
#   'navigate',
#   'south',
#   'study',
#   'understand',
#   'have',
#   'come',
#   'come',
#   'you',
#   'set',
#   'be',
#   'save',
#   'go',
#   'mars',
#   'mars',
#   'mars',
#   'be',
#   'die',
#   'mars',
#   'florida',
#   'florida',
#   'florida',
#   'florida',
#   'deal',
#   'mars',
#   'death',
#   'mars',
#   'mars',
#   'virtue',
#   'point',
#   'mars',
#   'the',
#   'neptune',
#   'mars',
#   'die',
#   'figure',
#   'get',
#   'mars',
#   'figure',
#   'get',
#   'get',
#   'mars',
#   'make',
#   'fck',
#   'come',
#   'jupiter',
#   'the',
#   'watch',
#   'me',
#   'make',
#   'go',
#   'look',
#   'catholic',
#   'my',
#   'see',
#   'say',
#   'radical',
#   'print',
#   'go',
#   'print',
#   'texas',
#   'be',
#   'texas',
#   'be',
#   'california',
#   'fck',
#   'live',
#   'sound',
#   'death',
#   'walk',
#   'sound',
#   'be',
#   'make',
#   'let',
#   'be',
#   'them',
#   'your',
#   'be',
#   'lie',
#   'them',
#   'lie',
#   'them',
#   'lie',
#   'them',
#   'think',
#   'santa',
#   'be',
#   'be',
#   'be',
#   'do',
#   'do',
#   'keep',
#   'school',
#   'school',
#   'figure',
#   'do',
#   'the',
#   'highfive',
#   'keep',
#   'be',
#   'push',
#   'bed',
#   'fck',
#   'bed',
#   'have',
#   'be',
#   'have',
#   'be',
#   'make',
#   'do',
#   'be',
#   'cause',
#   'say',
#   'a',
#   'find',
#   'have',
#   'pretend',
#   'eat',
#   'me',
#   'answer',
#   'think',
#   'each',
#   'jennifer',
#   'see',
#   'be',
#   'make',
#   'my',
#   'sleep',
#   'sleep',
#   'admit',
#   'a',
#   'myself',
#   'admit',
#   'have',
#   'live',
#   'survive',
#   'be',
#   'have',
#   'anyone',
#   'say',
#   'say',
#   'children',
#   'get',
#   'reveal',
#   'fame',
#   'ugly',
#   'why',
#   'read'],
#  'content': ['moviesmovie'],
#  'moviesmovie': ['reviewsmovie', 'reviewsmovie'],
#  'reviewsmovie': ['transcriptsstanley',
#   'transcriptsstanley',
#   'transcriptsstanley',
#   'transcriptsstanley'],
#  'transcriptsstanley': ['kubrickpauline',
#   'kubrickpauline',
#   'kubrickpauline',
#   'kubrickpauline'],
#  'kubrickpauline': ['kaeltv', 'kaeltv', 'kaeltv', 'kaeltv'],
#  'kaeltv': ['seriestv', 'seriestv', 'seriestv', 'seriestv'],
#  'seriestv': ['show', 'show', 'show', 'show'],
#  'show': ['transcriptscomedystandup',
#   'transcriptscomedystandup',
#   'transcriptscomedystandup',
#   'transcriptscomedystandup',
#   'up',
#   'the',
#   'and',
#   'me',
#   'transcriptsblog'],
#  'transcriptscomedystandup': ['comedy', 'comedy', 'comedy', 'comedy'],
#  'comedy': ['transcriptsgeorge',
#   'transcriptsgeorge',
#   'transcriptsgeorge',
#   'transcriptsgeorge',
#   'roots'],
#  'transcriptsgeorge': ['carlindave',
#   'carlindave',
#   'carlindave',
#   'carlindave',
#   'carlin'],
#  'carlindave': ['chappelleinterviewsplayboy',
#   'chappelleinterviewsplayboy',
#   'chappelleinterviewsplayboy',
#   'chappelleinterviewsplayboy'],
#  'chappelleinterviewsplayboy': ['interviewsmusichistorybooks',
#   'interviewsmusichistorybooks',
#   'interviewsmusichistorybooks',
#   'interviewsmusichistorybooks'],
#  'interviewsmusichistorybooks': ['menumoviesmovie',
#   'search',
#   'menumoviesmovie',
#   'searchcomedy'],
#  'menumoviesmovie': ['reviewsmovie', 'reviewsmovie'],
#  'search': ['moviesmovie'],
#  'searchcomedy': ['joe'],
#  '–': ['transcript', 'snl'],
#  'august': ['unleashing'],
#  'unleashing': ['his'],
#  'his': ['inquisitive',
#   'sneakers',
#   'house',
#   'dick',
#   'hair',
#   'dick',
#   'dad',
#   'car',
#   'fcking',
#   'own',
#   'house',
#   'fcking',
#   'neighborhood',
#   'state',
#   'jokes',
#   'neighbors',
#   'oil',
#   'ear',
#   'prestigious',
#   'comedy',
#   'rise'],
#  'inquisitive': ['intense'],
#  'intense': ['comedic'],
#  'comedic': ['style'],
#  'style': ['rogan'],
#  'explores': ['everything'],
#  'everything': ['from',
#   'men',
#   'men',
#   'men',
#   'was',
#   'seems',
#   'just',
#   'you',
#   'is'],
#  'why': ['no',
#   'are',
#   'its',
#   'we',
#   'am',
#   'did',
#   'do',
#   'someone',
#   'am',
#   'the',
#   'the',
#   'the',
#   'that',
#   'does',
#   'is',
#   'they',
#   'because',
#   'you',
#   'i',
#   'california',
#   'the',
#   'you',
#   'is',
#   'the',
#   'because',
#   'are',
#   'artists',
#   'every'],
#  'no': ['one',
#   'one',
#   'ones',
#   'boono',
#   'we',
#   'its',
#   'physical',
#   'i',
#   'works',
#   'doubt',
#   'doubt',
#   'i',
#   'edits',
#   'comic',
#   'this',
#   'this',
#   'what',
#   'witty',
#   'inspirational',
#   'idea',
#   'dates',
#   'you',
#   'no',
#   'they',
#   'loopholes',
#   'no',
#   'they',
#   'theres',
#   'socks',
#   'when',
#   'one',
#   'honey',
#   'the',
#   'one',
#   'level',
#   'the',
#   'use',
#   'ones',
#   'ones',
#   'such',
#   'who',
#   'way',
#   'longer'],
#  'one': ['wants',
#   'of',
#   'has',
#   'way',
#   'dude',
#   'of',
#   'hot',
#   'of',
#   'of',
#   'of',
#   'everybody',
#   'of',
#   'of',
#   'of',
#   'they',
#   'draft',
#   'religion',
#   'person',
#   'like',
#   'we',
#   'that',
#   'of',
#   'of',
#   'day',
#   'guy',
#   'of',
#   'of',
#   'of',
#   'knows',
#   'thats',
#   'just',
#   'thats',
#   'of',
#   'from',
#   'answer',
#   'thats',
#   'of',
#   'of',
#   'of'],
#  'wants': ['to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'conflict',
#   'to',
#   'to',
#   'to'],
#  'be': ['a',
#   'able',
#   'like',
#   'him',
#   'me',
#   'president',
#   'like',
#   'a',
#   'a',
#   'the',
#   'the',
#   'the',
#   'physically',
#   'matthew',
#   'amongst',
#   'like',
#   'able',
#   'like',
#   'before',
#   'there',
#   'done',
#   'nervous',
#   'nervous',
#   'over',
#   'in',
#   'ready',
#   'here',
#   'intoxicated',
#   'to',
#   'paranoid',
#   'one',
#   'the',
#   'the',
#   'honest',
#   'fcking',
#   'in',
#   'consistent',
#   'nice',
#   'more',
#   'the',
#   'diplomatic',
#   'honest',
#   'scared',
#   'only',
#   'worried',
#   'worried',
#   'you',
#   'alive',
#   'okay',
#   'happy',
#   'free',
#   'accepted',
#   'even',
#   'embarrassed',
#   'one',
#   'held',
#   'real',
#   'real',
#   'real',
#   'published'],
#  'a': ['president',
#   'pot',
#   'gummy',
#   'grateful',
#   'gray',
#   'bowl',
#   'dude',
#   'unit',
#   'lot',
#   'lot',
#   'difference',
#   'real',
#   'boat',
#   'person',
#   'fcking',
#   'dolphin',
#   'week',
#   'guy',
#   'chance',
#   'puff',
#   'dolphin',
#   'cerebral',
#   'human',
#   'language',
#   'dolphin',
#   'dolphin',
#   'dolphins',
#   'fcking',
#   'rapist',
#   'chick',
#   'goddamn',
#   'stupid',
#   'stupid',
#   'tube',
#   'chinese',
#   'blowjob',
#   'reality',
#   'plastic',
#   'president',
#   'foot',
#   'polar',
#   'closet',
#   'fck',
#   'girl',
#   'shaq',
#   'sixyearold',
#   'matter',
#   'wife',
#   'little',
#   'little',
#   'piece',
#   'bunch',
#   'chick',
#   'bunch',
#   'keyhole',
#   'fcking',
#   'fcking',
#   'problem',
#   'matter',
#   'lot',
#   'machete',
#   'map',
#   'suicide',
#   'door',
#   'dog',
#   'knife',
#   'guy',
#   'girl',
#   'girl',
#   'hard',
#   'im',
#   'lot',
#   'girl',
#   'girl',
#   'dudes',
#   'good',
#   'recognizable',
#   'photo',
#   'girl',
#   'fcking',
#   'twohole',
#   'lot',
#   'gal',
#   'winning',
#   'lot',
#   'regular',
#   'different',
#   'job',
#   'new',
#   'person',
#   'fck',
#   'girl',
#   'relationship',
#   'daily',
#   'new',
#   'person',
#   'person',
#   'very',
#   'girl',
#   'guy',
#   'nice',
#   'hero',
#   'few',
#   'rocket',
#   'mission',
#   'manned',
#   'oneway',
#   'bunch',
#   'day',
#   'salt',
#   'water',
#   'goddamn',
#   'crazy',
#   'dude',
#   'dirty',
#   'new',
#   'oneway',
#   'rocket',
#   'bible',
#   'metal',
#   'robot',
#   'metal',
#   'new',
#   'couple',
#   'scientology',
#   'neighbor',
#   'scientologist',
#   'wonderful',
#   'science',
#   'small',
#   'second',
#   'year',
#   'decade',
#   'good',
#   'captains',
#   'gold',
#   'dinner',
#   'recognized',
#   'cult',
#   'cult',
#   'religion',
#   'perfect',
#   'cult',
#   'religion',
#   'religion',
#   'loophole',
#   'child',
#   'sorcerer',
#   'golden',
#   'problem',
#   'cult',
#   'nice',
#   'good',
#   'perfect',
#   'hilarious',
#   'fullpage',
#   'mormon',
#   'good',
#   'good',
#   'good',
#   'dude',
#   'magazine',
#   'cop',
#   'cartoon',
#   'dark',
#   'draw',
#   'word',
#   'draw',
#   'draw',
#   'trap',
#   'wile',
#   'totally',
#   'bunch',
#   'snake',
#   'place',
#   'real',
#   'fcking',
#   'california',
#   'state',
#   'republic',
#   'fact',
#   'fact',
#   'tiger',
#   'sip',
#   'lot',
#   'different',
#   'problem',
#   'little',
#   'sixyearold',
#   'lot',
#   'baby',
#   'baby',
#   'baby',
#   'hug',
#   'lot',
#   'community',
#   'moron',
#   'little',
#   'year',
#   'weird',
#   'class',
#   'year',
#   'young',
#   'chimney',
#   'moment',
#   'sevenyearold',
#   'large',
#   'bunch',
#   'lot',
#   'room',
#   'bunch',
#   'kid',
#   'kid',
#   'level',
#   'salmon',
#   'cookout',
#   'part',
#   'recent',
#   'really',
#   'youtube',
#   'normal',
#   'normal',
#   'video',
#   'little',
#   'castle',
#   'lot',
#   'lot',
#   'btch',
#   'path',
#   'fcking',
#   'mountain',
#   'fcking',
#   'character',
#   'book',
#   'rebel',
#   'prisoner',
#   'cement',
#   'loner',
#   'calculation',
#   'bunch',
#   'btch',
#   'woman',
#   'mans',
#   'fck',
#   'praying',
#   'leaf',
#   'man',
#   'chick',
#   'fcking',
#   'close',
#   'very',
#   'clothing',
#   'cokedup',
#   'fcking',
#   'woman',
#   'chick',
#   'thumb',
#   'dress',
#   'lot',
#   'mountain',
#   'rose',
#   'man',
#   'great',
#   'selfie',
#   'comment',
#   'name',
#   'speech',
#   'box'],
#  'president': ['to',
#   'trump',
#   'trump',
#   'nobody',
#   'is',
#   'with',
#   'thats',
#   'the',
#   'he'],
#  'people': ['who',
#   'that',
#   'making',
#   'lived',
#   'what',
#   'the',
#   'you',
#   'yo',
#   'used',
#   'if',
#   'you',
#   'i',
#   'its',
#   'say',
#   'that',
#   'will',
#   'are',
#   'in',
#   'think',
#   'are',
#   'are',
#   'running',
#   'have',
#   'first',
#   'like',
#   'that',
#   'staring',
#   'staring',
#   'that',
#   'have',
#   'to',
#   'that',
#   'really',
#   'will',
#   'will',
#   'were',
#   'so',
#   'are',
#   'smart',
#   'out',
#   'and',
#   'and',
#   'i',
#   'being',
#   'have',
#   'in',
#   'and',
#   'got',
#   'those',
#   'that',
#   'didnt',
#   'and',
#   'and',
#   'in',
#   'around',
#   'invade',
#   'folks',
#   'are',
#   'say',
#   'who',
#   'theres',
#   'do',
#   'telling',
#   'theyre',
#   'in',
#   'in',
#   'in',
#   'came',
#   'came',
#   'have',
#   'have',
#   'have',
#   'they',
#   'come',
#   'by',
#   'i',
#   'but',
#   'believe',
#   'dumb',
#   'up',
#   'that',
#   'we',
#   'who',
#   'talking',
#   'dont',
#   'that',
#   'do',
#   'do',
#   'that',
#   'thats',
#   'that',
#   'the',
#   'who',
#   'so',
#   'that',
#   'like',
#   'dont',
#   'are',
#   'who',
#   'being'],
#  'who': ['comments',
#   'hates',
#   'broke',
#   'made',
#   'wants',
#   'broke',
#   'the',
#   'has',
#   'she',
#   'wrote',
#   'wrote',
#   'created',
#   'you',
#   'wear',
#   'have',
#   'are',
#   'is',
#   'homeschools',
#   'loves',
#   'is',
#   'theyre',
#   'leave',
#   'the',
#   'just',
#   'we',
#   'were',
#   'gives',
#   'didnt',
#   'starts'],
#  'comments': ['on', 'on', 'what', 'to'],
#  'on': ['youtube',
#   'san',
#   'and',
#   'a',
#   'fishhooks',
#   'a',
#   'dude',
#   'me',
#   'everyone',
#   'the',
#   'every',
#   'instagram',
#   'a',
#   'the',
#   'a',
#   'mars',
#   'mars',
#   'mars',
#   'but',
#   'i',
#   'you',
#   'why',
#   'with',
#   'a',
#   'a',
#   'the',
#   'man',
#   'boats',
#   'the',
#   'imagine',
#   'that',
#   'i',
#   'the',
#   'i',
#   'i',
#   'them',
#   'them',
#   'them',
#   'youtube',
#   'point',
#   'man',
#   'att',
#   'verizon',
#   'over',
#   'here',
#   'this',
#   'a',
#   'kanye',
#   'that',
#   'his',
#   'stage'],
#  'youtube': ['videos', 'videos', 'page', 'comments'],
#  'videos': ['from', 'who'],
#  'bruce': ['jenner',
#   'jenners',
#   'jenner',
#   'jenner',
#   'jenner',
#   'jenner',
#   'we',
#   'you',
#   'your'],
#  'jenner': ['to', 'oh', 'thing', 'and', 'lived'],
#  'debbie': ['ladies', 'wants', 'at', 'and', 'says', 'says', 'says', 'says'],
#  'ladies': ['and', 'and', 'and'],
#  'and': ['gentlemen',
#   'a',
#   'he',
#   'forth',
#   'its',
#   'eating',
#   'it',
#   'it',
#   'we',
#   'we',
#   'i',
#   'the',
#   'if',
#   'they',
#   'i',
#   'accidentally',
#   'all',
#   'looking',
#   'shit',
#   'you',
#   'like',
#   'it',
#   'dont',
#   'if',
#   'then',
#   'then',
#   'bruce',
#   'up',
#   'stupid',
#   'a',
#   'sucks',
#   'goes',
#   'we',
#   'a',
#   'i',
#   'his',
#   'i',
#   'he',
#   'she',
#   'shes',
#   'over',
#   'claim',
#   'theyll',
#   'they',
#   'its',
#   'no',
#   'a',
#   'it',
#   'why',
#   'fck',
#   'he',
#   'just',
#   'obama',
#   'in',
#   'shes',
#   'think',
#   'start',
#   'runs',
#   'shes',
#   'as',
#   'weirdos',
#   'perverts',
#   'true',
#   'then',
#   'say',
#   'moaning',
#   'gentlemen',
#   'they',
#   'they',
#   'strap',
#   'shoot',
#   'that',
#   'were',
#   'theyre',
#   'then',
#   'they',
#   'we',
#   'we',
#   'go',
#   'its',
#   'i',
#   'scientology',
#   'not',
#   'he',
#   'scientology',
#   'white',
#   'it',
#   'went',
#   'whats',
#   'my',
#   'you',
#   'i',
#   'part',
#   'it',
#   'trey',
#   'they',
#   'you',
#   'this',
#   'they',
#   'they',
#   'when',
#   'how',
#   'find',
#   'nobody',
#   'ill',
#   'modern',
#   'they',
#   'some',
#   'they',
#   'in',
#   'just',
#   'everybodys',
#   'concise',
#   'his',
#   'he',
#   'the',
#   'he',
#   'rubber',
#   'stinky',
#   'they',
#   'gentlemen',
#   'i',
#   'daddys',
#   'girl',
#   'so',
#   'you',
#   'no',
#   'shit',
#   'im',
#   'they',
#   'theyre',
#   'shes',
#   'shes',
#   'the',
#   'share',
#   'pretend',
#   'just',
#   'theres',
#   'they',
#   'the',
#   'go',
#   'thats',
#   'every',
#   'then',
#   'some',
#   'eve',
#   'all',
#   'this',
#   'one',
#   'eve',
#   'some',
#   'they',
#   'what',
#   'then',
#   'their',
#   'everybody',
#   'a',
#   'resolution',
#   'constant',
#   'im',
#   'eve',
#   'then',
#   'the',
#   'when',
#   'say',
#   'then',
#   'only',
#   'thats',
#   'people',
#   'not',
#   'had',
#   'child',
#   'neglect',
#   'shitty',
#   'the',
#   'theyre',
#   'their',
#   'like',
#   'just',
#   'fcking',
#   'you',
#   'i',
#   'listen',
#   'you',
#   'what',
#   'im',
#   'i',
#   'when',
#   'youre',
#   'some',
#   'my',
#   'youre',
#   'men',
#   'murderers',
#   'the',
#   'you',
#   'start',
#   'im',
#   'you',
#   'am',
#   'then',
#   'i',
#   'ive',
#   'i',
#   'he',
#   'neither',
#   'incredibly',
#   'kick',
#   'just',
#   'i',
#   'donald',
#   'why',
#   'where'],
#  'gentlemen': ['welcome', 'nobody', 'a'],
#  'welcome': ['joe'],
#  'roganwhat': ['the'],
#  'fck': ['is',
#   'whoo',
#   'down',
#   'are',
#   'man',
#   'are',
#   'we',
#   'up',
#   'they',
#   'when',
#   'out',
#   'them',
#   'that',
#   'are',
#   'her',
#   'her',
#   'her',
#   'they',
#   'in',
#   'the',
#   'my',
#   'everybody',
#   'you',
#   'did',
#   'did',
#   'is',
#   'about',
#   'are',
#   'are',
#   'are',
#   'are',
#   'were',
#   'the',
#   'believe',
#   'if',
#   'is',
#   'is',
#   'are',
#   'up',
#   'a',
#   'fck',
#   'fck',
#   'fck',
#   'fck',
#   'fck',
#   'fck',
#   'fck',
#   'fck',
#   'fck',
#   'and',
#   'youre',
#   'teachers',
#   'is',
#   'dad',
#   'your',
#   'your',
#   'you',
#   'out',
#   'are',
#   'are',
#   'with',
#   'is',
#   'up',
#   'you',
#   'out'],
#  'is': ['going',
#   'i',
#   'that',
#   'a',
#   'all',
#   'they',
#   'the',
#   'the',
#   'exactly',
#   'this',
#   'you',
#   'up',
#   'down',
#   'the',
#   'the',
#   'great',
#   'this',
#   'cooler',
#   'guarding',
#   'where',
#   'thats',
#   'experiencing',
#   'going',
#   'now',
#   'so',
#   'the',
#   'the',
#   'the',
#   'theyre',
#   'gonna',
#   'gonna',
#   'a',
#   'guarding',
#   'recognizable',
#   'a',
#   'take',
#   'a',
#   'a',
#   'her',
#   'it',
#   'a',
#   'im',
#   'just',
#   'so',
#   'gonna',
#   'not',
#   'what',
#   'that',
#   'a',
#   'that',
#   'i',
#   'a',
#   'still',
#   'legit',
#   'a',
#   'tom',
#   'going',
#   'a',
#   'bullshit',
#   'too',
#   'unanswered',
#   'the',
#   'the',
#   'this',
#   'proof',
#   'the',
#   'just',
#   'that',
#   'super',
#   'like',
#   'responsible',
#   'you',
#   'bullshit',
#   'bullshit',
#   'a',
#   'fcking',
#   'these',
#   'going',
#   'bullshit',
#   'real',
#   'bullshit',
#   'you',
#   'crazy',
#   'that',
#   'weird',
#   'i',
#   'where',
#   'alive',
#   'they',
#   'fcked',
#   'fcked',
#   'an',
#   'that',
#   'less',
#   'less',
#   'if',
#   'older',
#   'fck',
#   'years',
#   'it',
#   'awfulbut',
#   'not',
#   'the',
#   'playing',
#   'the',
#   'the',
#   'this',
#   'this',
#   'as',
#   'really',
#   'is',
#   'i',
#   'the',
#   'gonna',
#   'where',
#   'painted',
#   'this',
#   'going',
#   'gonna',
#   'put',
#   'leave',
#   'were',
#   'how',
#   'what',
#   'this',
#   'the',
#   'entirely',
#   'that',
#   'horribly',
#   'stressful'],
#  'going': ['on',
#   'this',
#   'on',
#   'in',
#   'fck',
#   'why',
#   'what',
#   'shes',
#   'youre',
#   'to',
#   'see',
#   'clear',
#   'on',
#   'on',
#   'to',
#   'on',
#   'on',
#   'on',
#   'on',
#   'out'],
#  'san': ['francisco', 'francisco', 'francisco', 'francisco'],
#  'francisco': ['thanks', 'this', 'heres', 'i'],
#  'thanks': ['for'],
#  'for': ['coming',
#   'its',
#   'like',
#   'him',
#   'getting',
#   'a',
#   'minutes',
#   'minutes',
#   'it',
#   'i',
#   'a',
#   'that',
#   'free',
#   'you',
#   'a',
#   'this',
#   'anybody',
#   'freedomwhats',
#   'ten',
#   'the',
#   'receiving'],
#  'coming': ['i', 'play'],
#  'i': ['appreciate',
#   'see',
#   'wasnt',
#   'was',
#   'love',
#   'think',
#   'asked',
#   'go',
#   'take',
#   'was',
#   'was',
#   'was',
#   'was',
#   'thought',
#   'was',
#   'started',
#   'could',
#   'was',
#   'watched',
#   'dont',
#   'think',
#   'started',
#   'was',
#   'was',
#   'lived',
#   'would',
#   'started',
#   'thought',
#   'mean',
#   'hope',
#   'have',
#   'dont',
#   'would',
#   'had',
#   'cant',
#   'know',
#   'cant',
#   'know',
#   'did',
#   'think',
#   'dont',
#   'should',
#   'have',
#   'have',
#   'could',
#   'dont',
#   'could',
#   'had',
#   'could',
#   'just',
#   'was',
#   'was',
#   'got',
#   'dont',
#   'could',
#   'dont',
#   'think',
#   'alone',
#   'alive',
#   'wanted',
#   'dont',
#   'mean',
#   'do',
#   'think',
#   'do',
#   'didnt',
#   'was',
#   'cant',
#   'bet',
#   'bet',
#   'just',
#   'mean',
#   'follow',
#   'care',
#   'care',
#   'dont',
#   'gotta',
#   'went',
#   'think',
#   'think',
#   'had',
#   'have',
#   'dont',
#   'dont',
#   'mean',
#   'dont',
#   'think',
#   'think',
#   'mean',
#   'watched',
#   'had',
#   'dont',
#   'guess',
#   'watched',
#   'cant',
#   'talked',
#   'dont',
#   'just',
#   'think',
#   'think',
#   'cant',
#   'draw',
#   'dont',
#   'dont',
#   'think',
#   'can',
#   'grew',
#   'grew',
#   'know',
#   'know',
#   'didnt',
#   'aint',
#   'get',
#   'had',
#   'love',
#   'have',
#   'lie',
#   'get',
#   'call',
#   'have',
#   'have',
#   'know',
#   'love',
#   'didnt',
#   'didnt',
#   'missed',
#   'missed',
#   'told',
#   'didnt',
#   'teach',
#   'teach',
#   'knew',
#   'dont',
#   'go',
#   'dont',
#   'dont',
#   'fcking',
#   'fcking',
#   'dont',
#   'dont',
#   'dont',
#   'dont',
#   'dont',
#   'was',
#   'dont',
#   'guess',
#   'shit',
#   'shit',
#   'hug',
#   'see',
#   'have',
#   'looked',
#   'mean',
#   'read',
#   'get',
#   'know',
#   'still',
#   'dont',
#   'think',
#   'sense',
#   'sense',
#   'live',
#   'just',
#   'think',
#   'see',
#   'still',
#   'gotta',
#   'gotta',
#   'dont',
#   'have',
#   'saying',
#   'dont',
#   'dont',
#   'want',
#   'dont',
#   'look',
#   'look',
#   'cant',
#   'cant',
#   'cant',
#   'was',
#   'was',
#   'had',
#   'appreciate',
#   'love',
#   'want'],
#  'appreciate': ['it', 'the'],
#  'it': ['god',
#   'looks',
#   'and',
#   'being',
#   'and',
#   'when',
#   'you',
#   'its',
#   'produces',
#   'lets',
#   'said',
#   'right',
#   'makes',
#   'means',
#   'all',
#   'doesnt',
#   'doesnt',
#   'and',
#   'iswell',
#   'i',
#   'had',
#   'into',
#   'oh',
#   'thinking',
#   'theres',
#   'but',
#   'gets',
#   'shes',
#   'no',
#   'science',
#   'like',
#   'would',
#   'we',
#   'it',
#   'takes',
#   'is',
#   'off',
#   'was',
#   'than',
#   'with',
#   'was',
#   'up',
#   'on',
#   'with',
#   'fcks',
#   'its',
#   'and',
#   'said',
#   'right',
#   'was',
#   'was',
#   'was',
#   'and',
#   'to',
#   'can',
#   'because',
#   'dont',
#   'up',
#   'up',
#   'they',
#   'elevated',
#   'plus',
#   'your',
#   'a',
#   'comes',
#   'you',
#   'out',
#   'nobody',
#   'they',
#   'was',
#   'but',
#   'was',
#   'wants',
#   'wouldnt',
#   'adam',
#   'up',
#   'even',
#   'might',
#   'or',
#   'thats',
#   'it',
#   'ends',
#   'as',
#   'btch',
#   'doesnt',
#   'been',
#   'been',
#   'damn',
#   'man',
#   'is',
#   'while',
#   'but',
#   'looks',
#   'looks',
#   'every',
#   'comin',
#   'youre',
#   'all',
#   'but',
#   'is',
#   'becomes',
#   'wants',
#   'wants',
#   'wants',
#   'can',
#   'can',
#   'putting'],
#  'god': ['damn', 'what', 'damn', 'im', 'im', 'youre', 'jokes', 'how', 'damn'],
#  'damn': ['put', 'how', 'it', 'it'],
#  'put': ['your', 'your', 'weed', 'them', 'a', 'me'],
#  'your': ['phone',
#   'phone',
#   'soul',
#   'liver',
#   'fingers',
#   'back',
#   'real',
#   'friend',
#   'kitchen',
#   'bathroom',
#   'roll',
#   'dude',
#   'dude',
#   'children',
#   'kid',
#   'baby',
#   'doll',
#   'baby',
#   'kids',
#   'kid',
#   'kid',
#   'kid',
#   'children',
#   'kids',
#   'dad',
#   'dad',
#   'kids',
#   'mom',
#   'kids',
#   'kids',
#   'mom',
#   'mothers',
#   'dad',
#   'children',
#   'shit',
#   'birth',
#   'lips'],
#  'phone': ['down', 'down', 'whoo', 'just', 'it'],
#  'down': ['fckface',
#   'motherfckers',
#   'oh',
#   'geary',
#   'is',
#   'this',
#   'to',
#   'the',
#   'she',
#   'on',
#   'bruce'],
#  'fckface': ['i'],
#  'see': ['you',
#   'the',
#   'em',
#   'theres',
#   'which',
#   'what',
#   'their',
#   'thats',
#   'any',
#   'it',
#   'em',
#   'how',
#   'it',
#   'em',
#   'the',
#   'so',
#   'em',
#   'when',
#   'just',
#   'if',
#   'what',
#   'it',
#   'this',
#   'what',
#   'what',
#   'a'],
#  'you': ['btch',
#   'trying',
#   'dont',
#   'eat',
#   'gotta',
#   'selling',
#   'trying',
#   'leave',
#   'smoke',
#   'get',
#   'eat',
#   'talk',
#   'expect',
#   'they',
#   'out',
#   'like',
#   'like',
#   'never',
#   'see',
#   'say',
#   'sound',
#   'really',
#   'lived',
#   'dont',
#   'dont',
#   'think',
#   'say',
#   'living',
#   'living',
#   'wanna',
#   'meet',
#   'just',
#   'boo',
#   'wont',
#   'fcks',
#   'vote',
#   'get',
#   'give',
#   'can',
#   'know',
#   'need',
#   'cant',
#   'cant',
#   'dont',
#   'have',
#   'trying',
#   'and',
#   'know',
#   'it',
#   'whats',
#   'wanna',
#   'doing',
#   'how',
#   'got',
#   'could',
#   'have',
#   'know',
#   'the',
#   'break',
#   'want',
#   'dont',
#   'had',
#   'think',
#   'get',
#   'drop',
#   'just',
#   'just',
#   'fcking',
#   'playing',
#   'know',
#   'cant',
#   'know',
#   'cant',
#   'just',
#   'look',
#   'saw',
#   'a',
#   'really',
#   'mmm',
#   'know',
#   'love',
#   'going',
#   'go',
#   'moving',
#   'might',
#   'cant',
#   'dont',
#   'talking',
#   'say',
#   'have',
#   'ever',
#   'as',
#   'hey',
#   'think',
#   'talking',
#   'fly',
#   'gotta',
#   'fck',
#   'great',
#   'find',
#   'are',
#   'can',
#   'havent',
#   'know',
#   'take',
#   'believe',
#   'wanna',
#   'people',
#   'made',
#   'talking',
#   'made',
#   'so',
#   'so',
#   'gotta',
#   'havent',
#   'know',
#   'enjoyed',
#   'wanna',
#   'wanna',
#   'know',
#   'know',
#   'if',
#   'draw',
#   'when',
#   'couldnt',
#   'couldnt',
#   'had',
#   'can',
#   'start',
#   'livin',
#   'ever',
#   'gotta',
#   'gotta',
#   'might',
#   'might',
#   'gonna',
#   'gonna',
#   'gonna',
#   'a',
#   'think',
#   'make',
#   'fckers',
#   'shouldnt',
#   'shouldnt',
#   'what',
#   'think',
#   'know',
#   'call',
#   'call',
#   'know',
#   'call',
#   'like',
#   'maybe',
#   'its',
#   'have',
#   'dont',
#   'have',
#   'have',
#   'dont',
#   'dont',
#   'dont',
#   'got',
#   'got',
#   'just',
#   'see',
#   'your',
#   'that',
#   'ever',
#   'ever',
#   'let',
#   'at',
#   'wanna',
#   'got',
#   'got',
#   'got',
#   'have',
#   'gotta',
#   'cant',
#   'make',
#   'gotta',
#   'gotta',
#   'cant',
#   'get',
#   'get',
#   'dont',
#   'have',
#   'gonna',
#   'have',
#   'dont',
#   'want',
#   'dont',
#   'gotta',
#   'can',
#   'can',
#   'know',
#   'look',
#   'shouldnt',
#   'factor',
#   'know',
#   'call',
#   'after',
#   'start',
#   'imagine',
#   'aint',
#   'think',
#   'dress',
#   'know',
#   'know',
#   'sure',
#   'doing',
#   'doing',
#   'fighting',
#   'white',
#   'saying',
#   'could',
#   'saying',
#   'gotta',
#   'said',
#   'i',
#   'have',
#   'have',
#   'dont',
#   'they',
#   'like',
#   'its',
#   'live',
#   'a',
#   'cant',
#   'cant',
#   'never',
#   'see',
#   'dont',
#   'a',
#   'a',
#   'piece',
#   'can',
#   'alone',
#   'do',
#   'find',
#   'this',
#   'right',
#   'know',
#   'should',
#   'wanna',
#   'should',
#   'should',
#   'do',
#   'live',
#   'become',
#   'put',
#   'show',
#   'to',
#   'dont',
#   'tell',
#   'dont',
#   'have',
#   'have',
#   'put',
#   'lying',
#   'should',
#   'better',
#   'were',
#   'i',
#   'no',
#   'say',
#   'fcking',
#   'know',
#   'very',
#   'savages',
#   'people',
#   'guys',
#   'very'],
#  'btch': ['put',
#   'theyre',
#   'where',
#   'were',
#   'you',
#   'thats',
#   'life',
#   'dont',
#   'every',
#   'right'],
#  'motherfckers': ['they'],
#  'they': ['cant',
#   'make',
#   'just',
#   'go',
#   'know',
#   'know',
#   'look',
#   'like',
#   'like',
#   'like',
#   'look',
#   'wouldnt',
#   'have',
#   'have',
#   'dont',
#   'dont',
#   'dont',
#   'have',
#   'stay',
#   'what',
#   'went',
#   'are',
#   'make',
#   'will',
#   'will',
#   'will',
#   'have',
#   'pulled',
#   'didnt',
#   'let',
#   'have',
#   'got',
#   'got',
#   'open',
#   'dont',
#   'went',
#   'probably',
#   'were',
#   'like',
#   'like',
#   'follow',
#   'look',
#   'go',
#   'talk',
#   'get',
#   'take',
#   'gotta',
#   'make',
#   'shoot',
#   'fill',
#   'dont',
#   'believe',
#   'got',
#   'just',
#   'dont',
#   'never',
#   'made',
#   'went',
#   'took',
#   'just',
#   'didnt',
#   'didnt',
#   'didnt',
#   'just',
#   'get',
#   'made',
#   'were',
#   'killed',
#   'got',
#   'promptly',
#   'had',
#   'were',
#   'were',
#   'were',
#   'became',
#   'stayed',
#   'landed',
#   'just',
#   'just',
#   'all',
#   'all',
#   'all',
#   'have',
#   'are',
#   'have',
#   'were',
#   'dont',
#   'have',
#   'can',
#   'went',
#   'got',
#   'yell',
#   'dont',
#   'say',
#   'dont',
#   'think',
#   'have',
#   'want',
#   'wanna',
#   'play',
#   'play',
#   'make',
#   'wanna',
#   'being',
#   'have',
#   'use',
#   'dont',
#   'dont',
#   'just',
#   'get',
#   'have',
#   'have',
#   'have',
#   'were',
#   'just',
#   'follow',
#   'can',
#   'hang',
#   'could',
#   'dont',
#   'watch',
#   'like',
#   'dont',
#   'know',
#   'see',
#   'just',
#   'just',
#   'just',
#   'constantly',
#   'just',
#   'steal',
#   'just',
#   'can',
#   'should',
#   'see',
#   'waited',
#   'knew',
#   'could'],
#  'cant': ['use',
#   'remember',
#   'understand',
#   'do',
#   'have',
#   'pretend',
#   'do',
#   'even',
#   'do',
#   'guard',
#   'do',
#   'quit',
#   'sleep',
#   'get',
#   'hang',
#   'live',
#   'believe',
#   'even',
#   'make',
#   'mix',
#   'talk',
#   'talk',
#   'say',
#   'say',
#   'the',
#   'i',
#   'be'],
#  'use': ['their', 'like', 'the', 'for', 'contact'],
#  'their': ['eyes',
#   'goddamn',
#   'world',
#   'ass',
#   'face',
#   'chest',
#   'guy',
#   'car',
#   'way',
#   'kid',
#   'kid',
#   'brain',
#   'gold',
#   'farts',
#   'cheez',
#   'shit',
#   'own',
#   'gender',
#   'true',
#   'designer'],
#  'eyes': ['everybodys'],
#  'everybodys': ['gotta', 'like', 'worried', 'take'],
#  'gotta': ['live',
#   'ask',
#   'be',
#   'be',
#   'go',
#   'build',
#   'stop',
#   'make',
#   'go',
#   'just',
#   'be',
#   'be',
#   'be',
#   'teach',
#   'be',
#   'teach',
#   'be',
#   'get',
#   'go',
#   'go'],
#  'live': ['through',
#   'in',
#   'in',
#   'man',
#   'in',
#   'cause',
#   'in',
#   'with',
#   'with',
#   'in',
#   'with',
#   'it'],
#  'through': ['their',
#   'the',
#   'different',
#   'different',
#   'a',
#   'the',
#   'the',
#   'space',
#   'the',
#   'it',
#   'no',
#   'surgery'],
#  'goddamn': ['phone', 'nerfedup', 'party'],
#  'whoo': ['im', 'its', 'im'],
#  'im': ['high',
#   'like',
#   'like',
#   'paralyzed',
#   'making',
#   'taking',
#   'getting',
#   'on',
#   'not',
#   'saying',
#   'the',
#   'not',
#   'getting',
#   'just',
#   'not',
#   'vegan',
#   'gonna',
#   'gonna',
#   'doing',
#   'doing',
#   'none',
#   'freaking',
#   'not',
#   'doing',
#   'watching',
#   'like',
#   'not',
#   'different',
#   'a',
#   'a',
#   'different',
#   'clear',
#   'back',
#   'back',
#   'talking',
#   'not',
#   'gonna',
#   'gonna',
#   'gonna',
#   'not',
#   'high',
#   'a',
#   'high',
#   'like',
#   'like',
#   'like',
#   'sorry',
#   'off',
#   'trying',
#   'like',
#   'gonna',
#   'gonna',
#   'gonna',
#   'like',
#   'not',
#   'becoming',
#   'not',
#   'like',
#   'like',
#   'kind',
#   'just',
#   'in',
#   'riding',
#   'also',
#   'not',
#   'saying',
#   'seeing',
#   'seeing',
#   'seeing'],
#  'high': ['as', 'i', 'i', 'around', 'i', 'is', 'around', 'im'],
#  'as': ['fck',
#   'being',
#   'us',
#   'me',
#   'if',
#   'if',
#   'good',
#   'giant',
#   'a',
#   'a',
#   'fck',
#   'a',
#   'being',
#   'michael',
#   'fck',
#   'funny',
#   'if',
#   'good',
#   'its',
#   'good',
#   'its',
#   'shit',
#   'he'],
#  'its': ['strange',
#   'not',
#   'some',
#   'not',
#   'not',
#   'processed',
#   'very',
#   'just',
#   'you',
#   'you',
#   'the',
#   'the',
#   'a',
#   'a',
#   'dumb',
#   'just',
#   'nonsense',
#   'so',
#   'not',
#   'not',
#   'not',
#   'way',
#   'one',
#   'most',
#   'unlocked',
#   'all',
#   'some',
#   'someone',
#   'one',
#   'more',
#   'nonsense',
#   'a',
#   'all',
#   'like',
#   'because',
#   'like',
#   'the',
#   'a',
#   'created',
#   'bullshit',
#   'a',
#   'too',
#   'fantastic',
#   'so',
#   'also',
#   'not',
#   'one',
#   'not',
#   'fcking',
#   'a',
#   'not',
#   'a',
#   'a',
#   'not',
#   'not',
#   'weird',
#   'weird',
#   'just',
#   'like',
#   'i',
#   'this',
#   'that',
#   'nothing',
#   'actually',
#   'like',
#   'debbie',
#   'not',
#   'not',
#   'like',
#   'a',
#   'about',
#   'how',
#   'the',
#   'as',
#   'ever',
#   'never',
#   'ever',
#   'just',
#   'just',
#   'happening',
#   'like',
#   'what',
#   'natural',
#   'just',
#   'at',
#   'like',
#   'mutiny',
#   'like',
#   'only',
#   'not',
#   'weird',
#   'also',
#   'environment'],
#  'strange': ['i', 'way'],
#  'wasnt': ['sure'],
#  'sure': ['if', 'about', 'nowhy'],
#  'if': ['i',
#   'youve',
#   'people',
#   'cheeseburgers',
#   'you',
#   'you',
#   'theyre',
#   'its',
#   'consciousness',
#   'me',
#   'thats',
#   'i',
#   'he',
#   'thats',
#   'everyone',
#   'thats',
#   'its',
#   'its',
#   'theres',
#   'theres',
#   'trump',
#   'i',
#   'the',
#   'were',
#   'theyre',
#   'i',
#   'you',
#   'there',
#   'theres',
#   'this',
#   'you',
#   'you',
#   'he',
#   'you',
#   'you',
#   'you',
#   'she',
#   'she',
#   'we',
#   'men',
#   'its',
#   'one',
#   'you',
#   'your',
#   'you',
#   'youve',
#   'people',
#   'you',
#   'you',
#   'scientology',
#   'i',
#   'you',
#   'you',
#   'you',
#   'i',
#   'other',
#   'the',
#   'the',
#   'i',
#   'im',
#   'youre',
#   'you',
#   'you',
#   'adam',
#   'you',
#   'jesus',
#   'jennifer',
#   'my',
#   'youve',
#   'you',
#   'my',
#   'you',
#   'you',
#   'you'],
#  'was': ['gonna',
#   'in',
#   'so',
#   'trying',
#   'spinning',
#   'so',
#   'gonna',
#   'thinking',
#   'thinking',
#   'like',
#   'in',
#   'guarding',
#   'petting',
#   'like',
#   'total',
#   'a',
#   'a',
#   'washington',
#   'inside',
#   'probably',
#   'probably',
#   'guarding',
#   'probably',
#   'here',
#   'probably',
#   'actually',
#   'going',
#   'just',
#   'gonna',
#   'like',
#   'written',
#   'one',
#   'like',
#   'like',
#   'a',
#   'a',
#   'in',
#   'outraged',
#   'nobody',
#   'a',
#   'weird',
#   'like',
#   'funny',
#   'like',
#   'a',
#   'like',
#   'a',
#   'in',
#   'i',
#   'born'],
#  'gonna': ['do',
#   'die',
#   'think',
#   'die',
#   'die',
#   'do',
#   'give',
#   'do',
#   'be',
#   'be',
#   'get',
#   'take',
#   'move',
#   'go',
#   'move',
#   'read',
#   'have',
#   'die',
#   'all',
#   'leave',
#   'make',
#   'hang',
#   'draw',
#   'be',
#   'do',
#   'do',
#   'mock',
#   'say',
#   'hang',
#   'tell',
#   'repeat',
#   'need',
#   'need',
#   'need',
#   'be',
#   'get',
#   'tell',
#   'be',
#   'go',
#   'go',
#   'be',
#   'have',
#   'make',
#   'shut',
#   'go',
#   'shit',
#   'see',
#   'cut',
#   'get',
#   'be',
#   'deal',
#   'think'],
#  'do': ['this',
#   'to',
#   'what',
#   'right',
#   'that',
#   'if',
#   'everything',
#   'exactly',
#   'everything',
#   'see',
#   'some',
#   'one',
#   'i',
#   'big',
#   'this',
#   'everything',
#   'this',
#   'you',
#   'what',
#   'next',
#   'you',
#   'you',
#   'this',
#   'this',
#   'this',
#   'you',
#   'and',
#   'you',
#   'we',
#   'speak',
#   'you',
#   'that',
#   'you',
#   'you',
#   'we',
#   'this',
#   'we',
#   'this',
#   'it',
#   'it',
#   'we',
#   'theyre',
#   'are',
#   'birds',
#   'i',
#   'the',
#   'right',
#   'know',
#   'all',
#   'its',
#   'if',
#   'anything',
#   'to',
#   'is',
#   'a',
#   'more',
#   'thats',
#   'its',
#   'whatever',
#   'you',
#   'but'],
#  'this': ['sober',
#   'is',
#   'dudes',
#   'way',
#   'is',
#   'weed',
#   'is',
#   'is',
#   'one',
#   'guy',
#   'fcking',
#   'motherfcker',
#   'what',
#   'guys',
#   'girl',
#   'girl',
#   'woman',
#   'is',
#   'is',
#   'is',
#   'guy',
#   'motherfcker',
#   'fck',
#   'is',
#   'is',
#   'and',
#   'place',
#   'i',
#   'for',
#   'up',
#   'this',
#   'is',
#   'different',
#   'im',
#   'is',
#   'is',
#   'dont',
#   'girl',
#   'is',
#   'before',
#   'girl',
#   'theres',
#   'fcking',
#   'crazy',
#   'dude',
#   'is',
#   'shit',
#   'but',
#   'musical',
#   'isnt',
#   'up',
#   'fcking',
#   'togetherthats',
#   'whole',
#   'plays',
#   'im',
#   'faggot',
#   'is',
#   'when',
#   'and',
#   'lady',
#   'thing',
#   'is',
#   'work',
#   'moment',
#   'is',
#   'fcking',
#   'is',
#   'light',
#   'chucked',
#   'fcking',
#   'is',
#   'is',
#   'what',
#   'what',
#   'what',
#   'life',
#   'is',
#   'show',
#   'is',
#   'pink',
#   'eventually',
#   'room',
#   'because',
#   'position',
#   'is',
#   'okay',
#   'bruce',
#   'is',
#   'is',
#   'discussed',
#   'just',
#   'article',
#   'field'],
#  'sober': ['im'],
#  'like': ['ugh',
#   'lawn',
#   'el',
#   'theres',
#   'the',
#   'um',
#   'minutes',
#   'check',
#   'pop',
#   'look',
#   'a',
#   'a',
#   'another',
#   'hopping',
#   'im',
#   'btch',
#   'what',
#   'that',
#   'people',
#   'im',
#   'a',
#   'a',
#   'a',
#   'that',
#   'whoa',
#   'an',
#   'i',
#   'youre',
#   'a',
#   'everybody',
#   'good',
#   'oh',
#   'like',
#   'theres',
#   'if',
#   'that',
#   'what',
#   'this',
#   'she',
#   'she',
#   'how',
#   'the',
#   'this',
#   'that',
#   'thats',
#   'those',
#   'btch',
#   'oh',
#   'puff',
#   'yeah',
#   'a',
#   'man',
#   'theyre',
#   'we',
#   'my',
#   'over',
#   'what',
#   'i',
#   'its',
#   'btch',
#   'first',
#   'a',
#   'i',
#   'a',
#   'thatoh',
#   'the',
#   'they',
#   'heres',
#   'champs',
#   'oh',
#   'they',
#   'each',
#   'that',
#   'the',
#   'we',
#   'yall',
#   'man',
#   'three',
#   'oh',
#   'shit',
#   'i',
#   'they',
#   'who',
#   'you',
#   'having',
#   'you',
#   'a',
#   'oh',
#   'dad',
#   'aw',
#   'when',
#   'oh',
#   'i',
#   'yeah',
#   'little',
#   'maddogging',
#   'oh',
#   'real',
#   'my',
#   'how',
#   'its',
#   'that',
#   'really',
#   'i',
#   'in',
#   'debbie',
#   'you',
#   'sweetie',
#   'the',
#   'i',
#   'i',
#   'how',
#   'that',
#   'it',
#   'it',
#   'an',
#   'macho',
#   'bullshit',
#   'you',
#   'the',
#   'little',
#   'dude',
#   'ill',
#   'why',
#   'i',
#   'oh',
#   'if',
#   'i',
#   'i',
#   'wow',
#   'needs',
#   'and',
#   'ill',
#   'youre',
#   'ill',
#   'that',
#   'this',
#   'bruce',
#   'that',
#   'what',
#   'a',
#   'a',
#   'you'],
#  'ugh': ['its', 'dear'],
#  'not': ['the',
#   'in',
#   'consistent',
#   'making',
#   'he',
#   'what',
#   'regulated',
#   'a',
#   'gonna',
#   'like',
#   'sleeping',
#   'sexist',
#   'sexist',
#   'equality',
#   'white',
#   'sexist',
#   'sexist',
#   'proud',
#   'that',
#   'making',
#   'like',
#   'water',
#   'gonna',
#   'just',
#   'by',
#   'in',
#   'in',
#   'in',
#   'in',
#   'making',
#   'santa',
#   'supposed',
#   'like',
#   'that',
#   'supposed',
#   'even',
#   'im',
#   'a',
#   'a',
#   'a',
#   'as',
#   'only',
#   'something',
#   'something',
#   'want',
#   'that',
#   'beating',
#   'a',
#   'sureis',
#   'unhappy',
#   'gonna',
#   'me',
#   'me',
#   'real',
#   'going',
#   'really',
#   'beautiful',
#   'be'],
#  'move': ['not', 'cause', 'back', 'to', 'to', 'when'],
#  'in': ['san',
#   'yet',
#   'there',
#   'hawaii',
#   'the',
#   'the',
#   'a',
#   'their',
#   'california',
#   'the',
#   'the',
#   'an',
#   'soccer',
#   'charge',
#   'this',
#   'that',
#   'thats',
#   'the',
#   'office',
#   'over',
#   'the',
#   'i',
#   'that',
#   'an',
#   'that',
#   'america',
#   'all',
#   'the',
#   'his',
#   'his',
#   'this',
#   'the',
#   'common',
#   'that',
#   'there',
#   'i',
#   'the',
#   'the',
#   'the',
#   'and',
#   'florida',
#   'the',
#   'the',
#   'the',
#   'the',
#   'america',
#   'detroit',
#   'your',
#   'front',
#   'coach',
#   'one',
#   'youre',
#   'his',
#   'his',
#   'his',
#   'a',
#   'a',
#   'order',
#   'a',
#   'evolving',
#   'the',
#   'the',
#   'the',
#   'shock',
#   'the',
#   'time',
#   'garland',
#   'garland',
#   'texas',
#   'a',
#   'texas',
#   'that',
#   'the',
#   'places',
#   'a',
#   'boston',
#   'boston',
#   'the',
#   'their',
#   'the',
#   'the',
#   'this',
#   'texas',
#   'texas',
#   'captivity',
#   'texas',
#   'private',
#   'all',
#   'dudes',
#   'texas',
#   'marin',
#   'peace',
#   'common',
#   'the',
#   'the',
#   'a',
#   'the',
#   'with',
#   'that',
#   'a',
#   'schoolmy',
#   'the',
#   'the',
#   'youre',
#   'some',
#   'real',
#   'my',
#   'between',
#   'a',
#   'are',
#   'the',
#   'my',
#   'the',
#   'a',
#   'the',
#   'real',
#   'solitary',
#   'a',
#   'some',
#   'denial',
#   'this',
#   'this',
#   'a',
#   'the',
#   'the',
#   'with',
#   'a',
#   'skirts',
#   'heavy',
#   'his',
#   'a',
#   'los'],
#  'love': ['pot', 'your', 'you', 'you', 'you'],
#  'pot': ['but', 'gummy', 'store'],
#  'but': ['the',
#   'everybody',
#   'when',
#   'im',
#   'you',
#   'if',
#   'we',
#   'if',
#   'if',
#   'its',
#   'you',
#   'people',
#   'i',
#   'im',
#   'they',
#   'im',
#   'you',
#   'if',
#   'if',
#   'he',
#   'its',
#   'in',
#   'its',
#   'one',
#   'along',
#   'the',
#   'they',
#   'when',
#   'you',
#   'you',
#   'you',
#   'its',
#   'its',
#   'unless',
#   'you',
#   'this',
#   'its',
#   'your',
#   'you',
#   'nobody',
#   'heres',
#   'before',
#   'they',
#   'they',
#   'what',
#   'you',
#   'i',
#   'when',
#   'eventually',
#   'youre',
#   'in',
#   'were',
#   'thats',
#   'surely',
#   'its'],
#  'that': ['are',
#   'bear',
#   'a',
#   'we',
#   'changed',
#   'means',
#   'close',
#   'close',
#   'way',
#   'fcking',
#   'we',
#   'shittyass',
#   'he',
#   'kind',
#   'thing',
#   'someone',
#   'women',
#   'seems',
#   'can',
#   'you',
#   'women',
#   'cat',
#   'man',
#   'i',
#   'girl',
#   'job',
#   'girl',
#   'job',
#   'job',
#   'were',
#   'were',
#   'makes',
#   'office',
#   'office',
#   'tries',
#   'no',
#   'people',
#   'there',
#   'much',
#   'they',
#   'good',
#   'start',
#   'move',
#   'they',
#   'have',
#   'they',
#   'they',
#   'nobody',
#   'girl',
#   'kind',
#   'kind',
#   'like',
#   'are',
#   'dont',
#   'people',
#   'theyre',
#   'water',
#   'doesnt',
#   'dudes',
#   'giant',
#   'is',
#   'is',
#   'is',
#   'we',
#   'fcking',
#   'you',
#   'created',
#   'you',
#   'hbo',
#   'even',
#   'why',
#   'person',
#   'dudes',
#   'you',
#   'good',
#   'one',
#   'will',
#   'have',
#   'spot',
#   'california',
#   'suck',
#   'i',
#   'the',
#   'everybody',
#   'will',
#   'possible',
#   'but',
#   'they',
#   'can',
#   'thing',
#   'i',
#   'tells',
#   'santa',
#   'kids',
#   'figures',
#   'santa',
#   'kids',
#   'people',
#   'chalkboard',
#   'yeah',
#   'big',
#   'santa',
#   'are',
#   'and',
#   'thats',
#   'if',
#   'before',
#   'true',
#   'are',
#   'work',
#   'work',
#   'what',
#   'whole',
#   'said',
#   'of',
#   'in',
#   'you',
#   'answer',
#   'fcking',
#   'we',
#   'is',
#   'freaks',
#   'no',
#   'in',
#   'she',
#   'fcking',
#   'are',
#   'all',
#   'not',
#   'we',
#   'dont',
#   'the',
#   'youre',
#   'like',
#   'youve',
#   'people',
#   'youre',
#   'you',
#   'people',
#   'shit',
#   'feeling',
#   'im',
#   'youre',
#   'definitely',
#   'maybe',
#   'isnt',
#   'list',
#   'beautiful',
#   'reflects'],
#  'are': ['making',
#   'you',
#   'these',
#   'the',
#   'you',
#   'you',
#   'these',
#   'i',
#   'they',
#   'that',
#   'right',
#   'you',
#   'all',
#   'fcking',
#   'we',
#   'you',
#   'amazing',
#   'just',
#   'always',
#   'my',
#   'you',
#   'you',
#   'assholes',
#   'noble',
#   'noble',
#   'signing',
#   'you',
#   'you',
#   'you',
#   'you',
#   'smart',
#   'literally',
#   'right',
#   'an',
#   'like',
#   'you',
#   'a',
#   'you',
#   'some',
#   'in',
#   'ya',
#   'you',
#   'you',
#   'more',
#   'in',
#   'sleeping',
#   'you',
#   'normally',
#   'they',
#   'hollow',
#   'a',
#   'you',
#   'gonna',
#   'crazy',
#   'the',
#   'made',
#   'the',
#   'that',
#   'those',
#   'monsters',
#   'your',
#   'we',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'different',
#   'on',
#   'you',
#   'you',
#   'you',
#   'the',
#   'weird',
#   'really',
#   'all',
#   'and',
#   'like',
#   'people',
#   'watching',
#   'on',
#   'we',
#   'you',
#   'my',
#   'too',
#   'you',
#   'marked'],
#  'making': ['edibles', 'these', 'them', 'eye', 'this', 'a', 'fun', 'shit'],
#  'edibles': ['need', 'one'],
#  'need': ['to',
#   'anything',
#   'your',
#   'to',
#   'him',
#   'more',
#   'those',
#   'some',
#   'some',
#   'those',
#   'other',
#   'people',
#   'people'],
#  'slow': ['the', 'your'],
#  'oh': ['my',
#   'shit',
#   'you',
#   'dude',
#   'my',
#   'my',
#   'no',
#   'people',
#   'really',
#   'my',
#   'i',
#   'my',
#   'the',
#   'jesus',
#   'no',
#   'i',
#   'im',
#   'shit',
#   'fcking',
#   'and',
#   'i',
#   'shut',
#   'thats'],
#  'my': ['god',
#   'life',
#   'life',
#   'face',
#   'favorite',
#   'favorite',
#   'cat',
#   'cat',
#   'favorite',
#   'emails',
#   'exwife',
#   'god',
#   'god',
#   'life',
#   'life',
#   'tax',
#   'friends',
#   'god',
#   'friend',
#   'beds',
#   'mom',
#   'mom',
#   'mom',
#   'mom',
#   'god',
#   'wifes',
#   'god',
#   'kid',
#   'daughter',
#   'kids',
#   'kids',
#   'dad',
#   'daughter',
#   'daughter',
#   'daughters',
#   'house',
#   'shirt',
#   'selfesteems',
#   'life',
#   'life',
#   'bars',
#   'manhood',
#   'wifes',
#   'manhood',
#   'stack',
#   'days',
#   'take',
#   'kids',
#   'dream'],
#  'what': ['are',
#   'youre',
#   'youre',
#   'the',
#   'that',
#   'it',
#   'we',
#   'if',
#   'if',
#   'if',
#   'if',
#   'if',
#   'if',
#   'if',
#   'if',
#   'i',
#   'are',
#   'im',
#   'the',
#   'the',
#   'this',
#   'the',
#   'kind',
#   'kind',
#   'are',
#   'the',
#   'the',
#   'im',
#   'her',
#   'is',
#   'the',
#   'great',
#   'we',
#   'that',
#   'the',
#   'does',
#   'hold',
#   'the',
#   'they',
#   'the',
#   'the',
#   'do',
#   'im',
#   'if',
#   'are',
#   'are',
#   'are',
#   'getting',
#   'do',
#   'your',
#   'the',
#   'did',
#   'the',
#   'to',
#   'the',
#   'its',
#   'you',
#   'to',
#   'we',
#   'happens',
#   'happens',
#   'the',
#   'a',
#   'youre',
#   'are',
#   'we',
#   'is',
#   'are',
#   'is',
#   'the',
#   'it',
#   'people',
#   'people',
#   'are',
#   'the',
#   'are',
#   'are',
#   'a',
#   'we',
#   'we',
#   'we',
#   'everybodys',
#   'you',
#   'im',
#   'im',
#   'im',
#   'kind',
#   'are',
#   'youre',
#   'youre',
#   'wait'],
#  'trying': ['to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to'],
#  'peoplei': ['had'],
#  'had': ['a',
#   'that',
#   'the',
#   'four',
#   'a',
#   'an',
#   'to',
#   'rounds',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'a',
#   'real',
#   'a',
#   'with',
#   'a'],
#  'gummy': ['bear', 'bear', 'bears'],
#  'bear': ['the', 'shouldnt', 'they', 'bursts'],
#  'other': ['day',
#   'what',
#   'assholes',
#   'guys',
#   'mens',
#   'every',
#   'people',
#   'right',
#   'planets',
#   'religions',
#   'cause',
#   'people',
#   'than',
#   'kids',
#   'kids',
#   'people',
#   'is',
#   'like',
#   'i',
#   'people',
#   'in'],
#  'day': ['i', 'they', 'like', 'the', 'you', 'my', 'its', 'of', 'they', 'two'],
#  'think': ['we',
#   'youre',
#   'of',
#   'what',
#   'of',
#   'of',
#   'women',
#   'i',
#   'women',
#   'theres',
#   'they',
#   'the',
#   'i',
#   'about',
#   'of',
#   'theres',
#   'i',
#   'im',
#   'hes',
#   'were',
#   'this',
#   'life',
#   'were',
#   'you',
#   'it',
#   'about',
#   'about',
#   'about',
#   'youre',
#   'whats',
#   'about',
#   'about',
#   'the',
#   'its',
#   'of',
#   'some',
#   'about',
#   'about',
#   'theyre',
#   'about',
#   'when'],
#  'we': ['can',
#   'could',
#   'were',
#   'were',
#   'were',
#   'lost',
#   'dont',
#   'do',
#   'cant',
#   'went',
#   'are',
#   'get',
#   'get',
#   'can',
#   'need',
#   'got',
#   'got',
#   'got',
#   'lose',
#   'have',
#   'gonna',
#   'really',
#   'get',
#   'get',
#   'cant',
#   'can',
#   'maybe',
#   'have',
#   'dont',
#   'got',
#   'gotta',
#   'do',
#   'are',
#   'get',
#   'gotta',
#   'just',
#   'never',
#   'never',
#   'stay',
#   'are',
#   'dont',
#   'wanna',
#   'got',
#   'dont',
#   'lost',
#   'need',
#   'stick',
#   'aint',
#   'could',
#   'cant',
#   'need',
#   'gotta',
#   'do',
#   'do',
#   'tell',
#   'dont',
#   'do',
#   'should',
#   'shouldnt',
#   'definitely',
#   'should',
#   'happy',
#   'wanted',
#   'have',
#   'have',
#   'need',
#   'adore',
#   'need',
#   'are',
#   'are',
#   'are',
#   'do',
#   'do',
#   'dont',
#   'all',
#   'lost',
#   'are',
#   'playing',
#   'would',
#   'got'],
#  'can': ['all',
#   'realize',
#   'figure',
#   'do',
#   'do',
#   'do',
#   'but',
#   'do',
#   'do',
#   'just',
#   'enjoy',
#   'google',
#   'be',
#   'prove',
#   'because',
#   'happen',
#   'be',
#   'manipulate',
#   'measure',
#   'see',
#   'only',
#   'kind',
#   'kind',
#   'kind',
#   'do',
#   'do',
#   'explain',
#   'be',
#   'be',
#   'be',
#   'be'],
#  'all': ['agree',
#   'happening',
#   'i',
#   'day',
#   'the',
#   'the',
#   'those',
#   'female',
#   'of',
#   'sorts',
#   'people',
#   'the',
#   'time',
#   'seen',
#   'over',
#   'she',
#   'the',
#   'the',
#   'its',
#   'that',
#   'come',
#   'gonna',
#   'those',
#   'scientology',
#   'talk',
#   'the',
#   'have',
#   'talk',
#   'in',
#   'of',
#   'shes',
#   'huddle',
#   'people',
#   'right',
#   'the',
#   'the',
#   'her',
#   'women',
#   'girls',
#   'girls',
#   'the',
#   'people',
#   'are',
#   'girls',
#   'these',
#   'right',
#   'like',
#   'in',
#   'of',
#   'a',
#   'an',
#   'the',
#   'the',
#   'are',
#   'im',
#   'dreams',
#   'you',
#   'rights'],
#  'agree': ['a', 'with'],
#  'shouldnt': ['be', 'do', 'be', 'be', 'be'],
#  'able': ['to', 'to'],
#  'steal': ['your', 'two'],
#  'soul': ['right'],
#  'right': ['how',
#   'and',
#   'they',
#   'now',
#   'back',
#   'people',
#   'into',
#   'so',
#   'if',
#   'mars',
#   'next',
#   'before',
#   'now',
#   'now',
#   'down',
#   'there',
#   'on',
#   'yeah',
#   'up',
#   'but',
#   'you',
#   'in',
#   'i',
#   'doesnt',
#   'there',
#   'im',
#   'everybody',
#   'now',
#   'now',
#   'politically',
#   'now'],
#  'how': ['the',
#   'strong',
#   'much',
#   'smart',
#   'smart',
#   'fcking',
#   'a',
#   'good',
#   'is',
#   'i',
#   'that',
#   'does',
#   'many',
#   'many',
#   'other',
#   'to',
#   'to',
#   'everything',
#   'obvious',
#   'many',
#   'they',
#   'this',
#   'i',
#   'is',
#   'does',
#   'the',
#   'do',
#   'does',
#   'you',
#   'some',
#   'would',
#   'would',
#   'many',
#   'olds',
#   'youre',
#   'much',
#   'im'],
#  'these': ['people',
#   'things',
#   'lines',
#   'dolphins',
#   'dolphins',
#   'fcking',
#   'dolphins',
#   'men',
#   'guys',
#   'people',
#   'answers',
#   'people',
#   'people',
#   'things',
#   'things',
#   'are',
#   'marbles',
#   'fcking'],
#  'things': ['man',
#   'because',
#   'is',
#   'as',
#   'freakin',
#   'no',
#   'get',
#   'about',
#   'that',
#   'i',
#   'but',
#   'man',
#   'you',
#   'to',
#   'i',
#   'i',
#   'confusing',
#   'that',
#   'that'],
#  'man': ['theyre',
#   'how',
#   'how',
#   'they',
#   'thats',
#   'who',
#   'i',
#   'im',
#   'but',
#   'you',
#   'we',
#   'i',
#   'if',
#   'i',
#   'we',
#   'so',
#   'theres',
#   'and',
#   'its',
#   'cause',
#   'i',
#   'what',
#   'get',
#   'for',
#   'so',
#   'stop',
#   'and',
#   'whos',
#   'who',
#   'nonsense',
#   'needs'],
#  'theyre': ['not',
#   'not',
#   'very',
#   'around',
#   'fcking',
#   'exactly',
#   'just',
#   'my',
#   'guarding',
#   'like',
#   'just',
#   'gonna',
#   'probably',
# ...
#  'broken': ['into'],
#  'obama': ['was', 'found', 'is', 'probably', 'actually'],
#  'office': ['the', 'no', 'that', 'is', 'like'],
#  'first': ['time',
#   'time',
#   'of',
#   'president',
#   'invented',
#   'of',
#   'of',
#   'guy',
#   'kid',
#   'comment'],
#  'over': ['years',
#   'time',
#   'time',
#   'two',
#   'online',
#   'you',
#   'it',
#   'there',
#   'what',
#   'cartoons',
#   'a',
#   'we',
#   'what'],
#  'years': ['that', 'old', 'old', 'old', 'old', 'who'],
#  'someone': ['broke', 'let', 'runs', 'what', 'you', 'who', 'even', 'elses'],
#  'broke': ['into', 'into', 'into', 'into', 'into'],
#  'guarding': ['the', 'the', 'the', 'him', 'me'],
#  'front': ['door', 'door', 'door', 'door', 'door', 'of'],
#  'door': ['by', 'im', 'oh', 'no', 'do', 'why', 'you', 'its'],
#  'herself': ['what', 'smacks'],
#  'women': ['cant', 'should', 'cant', 'can', 'are', 'who', 'if', 'okay'],
#  'men': ['can',
#   'cant',
#   'can',
#   'can',
#   'can',
#   'become',
#   'and',
#   'are',
#   'are',
#   'dont',
#   'dont'],
#  'saying': ['that', 'ridiculous', 'life', 'we', 'is', 'they', 'i', 'is'],
#  'seems': ['sexist', 'in', 'like'],
#  'sexist': ['right', 'no', 'heres', 'cause', 'to', 'as'],
#  'heres': ['why', 'why', 'why', 'a', 'how', 'what', 'why', 'my'],
#  'physical': ['equality', 'labor'],
#  'equality': ['folks', 'thats'],
#  'folks': ['thats', 'my', 'just', 'its', 'if', 'just', 'this'],
#  'olympics': ['cause'],
#  'guard': ['the', 'the', 'the', 'the', 'the'],
#  'ive': ['met', 'never', 'never', 'ever', 'never', 'got'],
#  'met': ['shaquille', 'santa', 'him', 'and'],
#  'shaquille': ['oneal'],
#  'oneal': ['and'],
#  'face': ['is', 'oh', 'of'],
#  'privilege': ['listen'],
#  'listen': ['if', 'if', 'if'],
#  'experiencing': ['a'],
#  'shaq': ['attack', 'if'],
#  'attack': ['im'],
#  'wrong': ['dude', 'with', 'with', 'with', 'not', 'gender'],
#  'save': ['the', 'the'],
#  'fear': ['factor', 'factor'],
#  'factor': ['with', 'guy', 'that'],
#  'holding': ['hands'],
#  'hands': ['itd', 'of'],
#  'itd': ['be'],
#  'sixyearold': ['at', 'daughter'],
#  'park': ['with', 'they'],
#  'dad': ['were', 'what', 'tell', 'tell', 'says', 'have', 'pussy'],
#  'barely': ['the'],
#  'labor': ['things'],
#  'giant': ['men', 'fcking', 'metal'],
#  'will': ['tell',
#   'just',
#   'just',
#   'just',
#   'wear',
#   'do',
#   'somebody',
#   'ecobro',
#   'find',
#   'kill',
#   'change',
#   'go',
#   'not'],
#  'tell': ['you', 'you', 'you', 'you', 'other', 'em', 'you', 'you', 'me'],
#  'iswell': ['im'],
#  'matter': ['of', 'of'],
#  'fact': ['my', 'i', 'a', 'about', 'shes'],
#  'favorite': ['people', 'people', 'stories'],
#  'female': ['i'],
#  'wife': ['and'],
#  'daughters': ['theyre', 'i', 'class', 'like'],
#  'beat': ['the', 'up'],
#  'okay': ['listen',
#   'yeah',
#   'its',
#   'were',
#   'thats',
#   'you',
#   'im',
#   'and',
#   'ill',
#   'okay',
#   'okay',
#   'okaybut',
#   'cause',
#   'you',
#   'are'],
#  'cocky': ['but'],
#  'confident': ['i', 'one', 'if', 'and'],
#  'flu': ['okay'],
#  'yeah': ['were',
#   'btch',
#   'i',
#   'what',
#   'my',
#   'you',
#   'nature',
#   'how',
#   'well',
#   'exactlydebbies',
#   'that',
#   'id'],
#  'cat': ['too', 'up', 'once'],
#  'proud': ['of'],
#  'whats': ['up', 'a', 'interesting', 'the', 'going', 'going', 'in'],
#  'bet': ['money', 'money', 'if', 'if'],
#  'ill': ['fck', 'tell', 'be', 'wait', 'come', 'deal', 'do', 'keep'],
#  'likely': ['cats', 'that'],
#  'cats': ['are'],
#  'petting': ['my'],
#  'bit': ['me', 'of'],
#  'whoa': ['are', 'yeah'],
#  'doing': ['here',
#   'it',
#   'it',
#   'combo',
#   'this',
#   'are',
#   'more',
#   'youre',
#   'this'],
#  'here': ['i',
#   'you',
#   'right',
#   'this',
#   'im',
#   'are',
#   'i',
#   'ugh',
#   'its',
#   'why',
#   'tonight'],
#  'little': ['nervous',
#   'nervous',
#   'high',
#   'people',
#   'bit',
#   'meetings',
#   'prisoners',
#   'papiermâché',
#   'humans',
#   'hole',
#   'tiny',
#   'ears',
#   'more',
#   'compromises',
#   'raptors'],
#  'nervous': ['got', 'women', 'you', 'in'],
#  'guys': ['a', 'that', 'that', 'in', 'will', 'will', 'are', 'who', 'thank'],
#  'piece': ['of', 'of'],
#  'leaving': ['too'],
#  'total': ['bullshit', 'bullshithowd', 'sense'],
#  'bullshit': ['total',
#   'its',
#   'in',
#   'cause',
#   'cause',
#   'okay',
#   'she',
#   'no',
#   'the',
#   'toughguy'],
#  'bullshithowd': ['that'],
#  'let': ['her', 'him', 'me', 'this', 'the', 'him', 'me', 'me'],
#  'bunch': ['of', 'of', 'of', 'of', 'of', 'of', 'of'],
#  'boss': ['was'],
#  'she': ['hated',
#   'has',
#   'does',
#   'sticks',
#   'has',
#   'doesnt',
#   'doesnt',
#   'get',
#   'turns',
#   'deletes',
#   'is',
#   'didnt',
#   'came',
#   'was',
#   'took',
#   'built',
#   'turns'],
#  'hated': ['her'],
#  'possible': ['look', 'because', 'im', 'that', 'if'],
#  'hot': ['girl', 'forever'],
#  'shes': ['working',
#   'a',
#   'got',
#   'just',
#   'just',
#   'my',
#   'thinking',
#   'thinking',
#   'thinking',
#   'a',
#   'writing',
#   'beautiful',
#   'beautiful',
#   'not'],
#  'working': ['with'],
#  'works': ['getting'],
#  'done': ['in', 'they'],
#  'audition': ['to'],
#  'gets': ['to', 'to', 'crazy', 'you', 'in', 'in'],
#  'each': ['one',
#   'other',
#   'other',
#   'other',
#   'other',
#   'other',
#   'other',
#   'other'],
#  'slowly': ['start', 'but'],
#  'start': ['to',
#   'morphing',
#   'saying',
#   'cause',
#   'looking',
#   'getting',
#   'fcking',
#   'throwing',
#   'looking',
#   'poking',
#   'they',
#   'doing'],
#  'morph': ['to'],
#  'likes': ['men', 'to'],
#  'become': ['like', 'one'],
#  'octopus': ['that'],
#  'tries': ['to'],
#  'fit': ['its'],
#  'keyhole': ['theres'],
#  'whos': ['like', 'in', 'a', 'dumber', 'lived', 'made'],
#  'definitely': ['guard', 'should', 'worry', 'maybe', 'people', 'there'],
#  'doubt': ['no', 'and'],
#  'woman': ['doesnt', 'who', 'trapped', 'whos'],
#  'claim': ['him'],
#  'morphing': ['and'],
#  'theyll': ['just', 'just'],
#  'ridiculous': ['preposterous'],
#  'preposterous': ['shit'],
#  'amazing': ['plus'],
#  'plus': ['im', 'i'],
#  'vegan': ['and'],
#  'wear': ['patchouli', 'nonironic'],
#  'patchouli': ['they'],
#  'next': ['thing', 'to'],
#  'poor': ['fcking'],
#  'am': ['i', 'i', 'i', 'i'],
#  'alone': ['the', 'were'],
#  'story': ['is', 'of', 'cause', 'this', 'about'],
#  'bananas': ['and', 'what'],
#  'stories': ['so'],
#  'breakin': ['at'],
#  'edits': ['and'],
#  'comic': ['exaggerations'],
#  'exaggerations': ['this'],
#  'grand': ['conspiracy'],
#  'conspiracy': ['theres'],
#  'cabal': ['of'],
#  'evil': ['geniuses'],
#  'strings': ['on'],
#  'america': ['its', 'to', 'you', 'believes', 'great'],
#  'sorts': ['of'],
#  'walks': ['of'],
#  'always': ['worried', 'been', 'been'],
#  'worried': ['the', 'about', 'about', 'about', 'about'],
#  'governments': ['checking', 'watching'],
#  'checking': ['out'],
#  'watching': ['us', 'this', 'the'],
#  'pulled': ['this'],
#  'two': ['months',
#   'rifles',
#   'months',
#   'dudes',
#   'tigers',
#   'things',
#   'people',
#   'people',
#   'answer',
#   'they',
#   'marbles',
#   'more',
#   'thumbs'],
#  'months': ['before', 'later', 'of', 'till'],
#  'before': ['he', 'and', 'the', 'the', 'you', 'you', 'i', 'i'],
#  'four': ['handguns', 'people'],
#  'handguns': ['two'],
#  'rifles': ['and'],
#  'machete': ['with'],
#  'didnt': ['even',
#   'think',
#   'get',
#   'get',
#   'kill',
#   'evolve',
#   'know',
#   'expect',
#   'expect',
#   'believe',
#   'mean',
#   'come'],
#  'map': ['on', 'was'],
#  'washington': ['and'],
#  'x': ['where'],
#  'later': ['this'],
#  'break': ['into', 'into'],
#  'want': ['to',
#   'to',
#   'your',
#   'your',
#   'your',
#   'to',
#   'to',
#   'to',
#   'even',
#   'to',
#   'to',
#   'you',
#   'to'],
#  'suicide': ['run'],
#  'run': ['thats', 'the', 'shit'],
#  'only': ['reason',
#   'one',
#   'makes',
#   'nonsense',
#   'one',
#   'are',
#   'two',
#   'two',
#   'measure',
#   'of',
#   'are',
#   'two'],
#  'reason': ['why'],
#  'runs': ['toward', 'away'],
#  'toward': ['the'],
#  'security': ['do', 'are'],
#  'snipers': ['on'],
#  'corner': ['they'],
#  'lasers': ['in'],
#  'grass': ['if'],
#  'far': ['they'],
#  'open': ['up', 'letter'],
#  'drop': ['right'],
#  'jail': ['nope', 'will'],
#  'nope': ['turns'],
#  'turns': ['out', 'on', 'out', 'him'],
#  'dog': ['you', 'shit'],
#  'made': ['it', 'a', 'me', 'me', 'a', 'cartoons', 'it', 'out', 'hundreds'],
#  'rounds': ['of'],
#  'ammunition': ['in'],
#  'car': ['left', 'going', 'just', 'dude', 'stupid', 'in'],
#  'left': ['that'],
#  'took': ['a', 'out', 'it', 'her'],
#  'knife': ['thats'],
#  'sitting': ['in', 'on'],
#  'government': ['fck', 'of', 'of'],
#  'exwife': ['and'],
#  'sprinting': ['oh'],
#  'step': ['this', 'of', 'of', 'in'],
#  'last': ['step', 'step', 'kid'],
#  'unlocked': ['he'],
#  'smacks': ['her'],
#  'ground': ['and'],
#  'starts': ['running', 'screaming', 'running', 'a'],
#  'running': ['through', 'around', 'in', 'shit'],
#  'hall': ['ah'],
#  'ah': ['hes'],
#  'alive': ['hes', 'back', 'yeah'],
#  'inside': ['for'],
#  'tackled': ['by'],
#  'offduty': ['officer'],
#  'officer': ['he'],
#  'wanted': ['to', 'to', 'to', 'i'],
#  'somebody': ['please', 'had'],
#  'please': ['shoot', 'visit'],
#  'shoot': ['me', 'it', 'that'],
#  'pissed': ['where'],
#  'tax': ['dollars'],
#  'dollars': ['going', 'through'],
#  'imagine': ['when', 'if', 'if', 'people'],
#  'found': ['out', 'a'],
#  'diversity': ['i'],
#  'playing': ['fcking', 'field', 'they', 'here'],
#  'fairy': ['tale'],
#  'tale': ['games'],
#  'hereobamas': ['got'],
#  'hard': ['job'],
#  'google': ['was', 'his', 'it'],
#  'own': ['name', 'not'],
#  'name': ['if', 'transcriptdave'],
#  'crazy': ['in',
#   'were',
#   'race',
#   'people',
#   'oneway',
#   'fck',
#   'over',
#   'people',
#   'people',
#   'yeah',
#   'my',
#   'btches'],
#  'night': ['right', 'you'],
#  'hed': ['just'],
#  'none': ['of', 'of'],
#  'freakin': ['out'],
#  'common': ['in', 'other'],
#  'quit': ['once'],
#  'actually': ['got', 'gonna', 'a'],
#  'morning': ['mr', 'and'],
#  'mr': ['president'],
#  'freaking': ['out'],
#  'kill': ['me', 'anybody', 'anybody', 'you'],
#  'hallway': ['theres'],
#  'selfies': ['thatd'],
#  'thatd': ['be'],
#  'greatest': ['selfie', 'time'],
#  'selfie': ['of', 'shit'],
#  'duck': ['lips'],
#  'lips': ['in', 'okay', 'are'],
#  'background': ['a', 'a', 'dancers'],
#  'breaking': ['into'],
#  'seen': ['this', 'i', 'it', 'in', 'any'],
#  'recognizable': ['pigeontoed', 'pose'],
#  'pigeontoed': ['is'],
#  'away': ['that', 'from', 'the', 'its', 'from'],
#  'pose': ['when'],
#  'original': ['pictures'],
#  'pictures': ['back', 'everybody', 'of', 'you', 'it', 'word'],
#  'stood': ['there'],
#  'hungry': ['like'],
#  'saw': ['a', 'a'],
#  'photo': ['from'],
#  'traveler': ['nobody'],
#  'knew': ['that', 'the', 'that', 'he'],
#  'combo': ['a', 'attractor'],
#  'twohole': ['combo'],
#  'attractor': ['its'],
#  'online': ['it', 'and'],
#  'likesi': ['saw'],
#  'gal': ['on'],
#  'instagram': ['she'],
#  'eight': ['million', 'million', 'million', 'million', 'million'],
#  'followers': ['all'],
#  'winning': ['formula'],
#  'formula': ['she'],
#  'sticks': ['with'],
#  'witty': ['memes'],
#  'memes': ['theres'],
#  'inspirational': ['quotes'],
#  'quotes': ['mnhmnh'],
#  'mnhmnh': ['mnhmnh', 'just'],
#  'ways': ['and', 'for'],
#  'regular': ['girl'],
#  'idea': ['what'],
#  'voice': ['sounds', 'of'],
#  'sounds': ['like', 'even'],
#  'occupation': ['that'],
#  'follow': ['theyre', 'her', 'the'],
#  'staring': ['at', 'at', 'at'],
#  'new': ['kind', 'frog', 'kind', 'house', 'metal', 'thing'],
#  'psychologically': ['thats'],
#  'navigate': ['those'],
#  'science': ['should', 'fiction'],
#  'south': ['america', 'park'],
#  'study': ['some'],
#  'frog': ['that'],
#  'gives': ['a', 'a'],
#  'florida': ['with', 'ill', 'we', 'why', 'man'],
#  'keep': ['a', 'filling', 'the', 'lying', 'that'],
#  'relationship': ['what'],
#  'many': ['dick', 'dick', 'times', 'more', 'people'],
#  'pics': ['does', 'does', 'from'],
#  'sent': ['how'],
#  'receive': ['on'],
#  'daily': ['basis'],
#  'basis': ['is'],
#  'national': ['debt'],
#  'debt': ['counter'],
#  'counter': ['was'],
#  'control': ['constantly'],
#  'constantly': ['i', 'fck'],
#  'notifications': ['her'],
#  'screaming': ['and'],
#  'deletes': ['all'],
#  'physically': ['lighter'],
#  'lighter': ['this'],
#  'influence': ['that'],
#  'attractant': ['thats'],
#  'drug': ['to'],
#  'creeps': ['and'],
#  'weirdos': ['and'],
#  'perverts': ['objectifying'],
#  'objectifying': ['her'],
#  'care': ['i', 'about', 'what'],
#  'nice': ['person', 'friendly', 'theyre', 'people', 'people'],
#  'hero': ['or', 'moves'],
#  'noble': ['men', 'and', 'one'],
#  'true': ['mmm', 'and', 'form'],
#  'mmm': ['if', 'oheveryone'],
#  'come': ['if',
#   'we',
#   'people',
#   'with',
#   'on',
#   'we',
#   'we',
#   'from',
#   'on',
#   'on',
#   'home',
#   'out'],
#  'sméagollike': ['real'],
#  'quick': ['just', 'here'],
#  'few': ['months'],
#  'dates': ['mesus'],
#  'mesus': ['is', 'meets', 'is'],
#  'disappointed': ['with'],
#  'mens': ['mesus', 'talks'],
#  'meets': ['mesus'],
#  'embarrassed': ['at', 'at'],
#  'talks': ['to', 'about', 'about'],
#  'oheveryone': ['wants'],
#  'themselves': ['up'],
#  'matthew': ['mcconaughey'],
#  'mcconaughey': ['to'],
#  'rocket': ['ship', 'travel', 'ever'],
#  'ship': ['theres'],
#  'signing': ['up'],
#  'mars': ['do',
#   'a',
#   'where',
#   'theyre',
#   'thats',
#   'youd',
#   'sucks',
#   'people',
#   'its',
#   'well',
#   'cause',
#   'a',
#   'with',
#   'man',
#   'theyre',
#   'arent'],
#  'mission': ['to', 'to'],
#  'manned': ['mission'],
#  'signed': ['up'],
#  'amongst': ['the'],
#  'oneway': ['trip', 'trip', 'trip'],
#  'trip': ['to', 'to', 'in'],
#  'sad': ['shit', 'shit'],
#  'reasons': ['first', 'why'],
#  'friends': ['right', 'is', 'and', 'with'],
#  'friend': ['if', 'was', 'was'],
#  'hang': ['out', 'back', 'back', 'back', 'up'],
#  'moving': ['to', 'to', 'to'],
#  'might': ['be', 'starve', 'freeze', 'be'],
#  'deal': ['with', 'with', 'with'],
#  'visit': ['each', 'our'],
#  'death': ['valley', 'one'],
#  'valley': ['look'],
#  'worse': ['get'],
#  'jesus': ['christ', 'christ', 'christ', 'fcking'],
#  'christ': ['theres', 'i', 'himself', 'what'],
#  'places': ['in', 'with'],
#  'detroit': ['why'],
#  'consider': ['moving'],
#  'dumbest': ['ideas'],
#  'ideas': ['ever'],
#  'ecobro': ['you'],
#  'ecobroed': ['these'],
#  'find': ['an', 'out', 'out', 'them', 'them', 'someone', 'things'],
#  'opportunity': ['to'],
#  'virtue': ['signal'],
#  'signal': ['over'],
#  'michael': ['shermer'],
#  'shermer': ['likes'],
#  'point': ['out', 'oh'],
#  'chest': ['out'],
#  'better': ['than', 'than', 'we', 'come', 'this', 'pink', 'pink', 'if'],
#  'seriously': ['you'],
#  'paid': ['attention'],
#  'attention': ['man'],
#  'maybe': ['should',
#   'okay',
#   'debbies',
#   'its',
#   'definitely',
#   'definitely',
#   'if',
#   'or',
#   'bruce',
#   'they'],
#  'colonize': ['mars'],
#  'californias': ['almost'],
#  'almost': ['out', 'instantly'],
#  'hell': ['nod'],
#  'nod': ['like'],
#  'fly': ['over', 'i'],
#  'takes': ['a'],
#  'worlds': ['blue', 'ever', 'gone'],
#  'blue': ['its'],
#  'salt': ['problem', 'out'],
#  'suck': ['the', 'they', 'but', 'sometimeslife', 'maybe', 'its'],
#  'party': ['instead'],
#  'instead': ['of'],
#  'pissing': ['and'],
#  'moaning': ['too'],
#  'complicated': ['bro'],
#  'neptune': ['oh'],
#  'race': ['filled'],
#  'dirty': ['house', 'secret'],
#  'build': ['a'],
#  'shitting': ['in'],
#  'kitchen': ['stop'],
#  'piling': ['up'],
#  'newspapers': ['youre'],
#  'read': ['in', 'their', 'more', 'more'],
#  'bathroom': ['you'],
#  'coach': ['with'],
#  'willing': ['to'],
#  'conversation': ['youre'],
#  'enough': ['to', 'to', 'to', 'to', 'to', 'to', 'you'],
#  'arent': ['going', 'that'],
#  'travel': ['ladies'],
#  'launch': ['and'],
#  'german': ['and'],
#  'concrete': ['bunkers'],
#  'bunkers': ['they'],
#  'squarejawed': ['cornfed'],
#  'cornfed': ['dude'],
#  'country': ['tuck'],
#  'tuck': ['a'],
#  'bible': ['under', 'possible'],
#  'under': ['that'],
#  'arm': ['and'],
#  'strap': ['him'],
#  'metal': ['dick', 'dick', 'dick', 'dick'],
#  'off': ['into', 'by', 'in', 'their'],
#  'heavens': ['thats'],
#  'robot': ['dick'],
#  'sky': ['we'],
#  'literally': ['trying'],
#  'tip': ['of'],
#  'onto': ['other'],
#  'planets': ['our', 'pregnant'],
#  'our': ['ultimate',
#   'struggle',
#   'website',
#   'conversations',
#   'weekly',
#   'archive'],
#  'ultimate': ['goal'],
#  'goal': ['is'],
#  'pregnant': ['and'],
#  'jupiter': ['then', 'up'],
#  'fill': ['jupiter'],
#  'filling': ['the'],
#  'cosmos': ['up'],
#  'evolve': ['and', 'in'],
#  'change': ['we', 'the'],
#  'perfect': ['like', 'definition', 'example'],
#  'church': ['of'],
#  'scientology': ['right', 'documentary', 'is', 'is', 'is', 'they'],
#  'eternal': ['being'],
#  'created': ['reality', 'by', 'south'],
#  'enjoy': ['iti'],
#  'iti': ['watched'],
#  'hbo': ['documentary'],
#  'couple': ['too'],
#  'clear': ['i', 'im', 'a', 'and'],
#  'havent': ['seen', 'seen'],
#  'neighbor': ['whos'],
#  'scientologist': ['and'],
#  'gay': ['i'],
#  'sleeps': ['really'],
#  'beds': ['here', 'like'],
#  'walls': ['hes'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
generate_sentence(ali_dict)
# Out:
# 'Atlanta and he was a box spring iliza remains the outside of options when they.'

# %%
generate_sentence(joe_dict)
# Out:
# 'Bet if adam and some real every corner they go to make this fcking dudes.'

# %%
import random
import string

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''
    
    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        sentence += ' ' + word2

        # Check if the word ends with a punctuation mark
        if word2[-1] in string.punctuation:
            break

        # Stop if we reach the desired sentence length
        if i == count-2:
            break

        word1 = word2

    # End it with a random punctuation mark
    sentence += random.choice(string.punctuation)
    return sentence

# %%
generate_sentence(ali_dict)
# Out:
# 'Unspoken understanding uh between each other homeless dude believe he doesnt have to get huge+'

# %%
generate_sentence(joe_dict)
# Out:
# 'Pop out a dog shit they have at anybody would be me i asked a='

# %%
##In this updated function, we use the string.punctuation constant to check if
##a word ends with a punctuation mark. If it does, we stop generating the sentence. We also use the random.choice function to select a random punctuation mark to end the sentence with.
